# %%
from SEIRNetwork import SEIRNetwork
from Simulation import Simulation
from Simulator import Simulator
from matplotlib.pyplot import figure
from collections import Counter
import networkx as nx

# %%
SEIR_network = SEIRNetwork()
simulator = Simulator(SEIR_network)
simulator.generate_simulation(T = 120)
simulator.set_imported_case(time=1, average_introductions_per_day=1.0)
simulator.set_social_distancing(time=1,global_rate=0.001)
simulator.run()
from matplotlib.pyplot import figure

figure(figsize=(15,5))
simulator.model.figure_infections(
    plot_S=False,
    plot_E=False,
    plot_I_pre=False,
    plot_I_sym='stacked',
    plot_Q_sym='stacked',
    plot_Q_pre=False,
    plot_Q_asym=False,
    plot_I_asym=False,
    show=False,
    combine_Q_infected=False,
    plot_percentages=False,
    scaled=True
)
# Out:
# Generated overall age distribution:
# 0-4: 0.0684	(0.0236 from target)
# 10-14: 0.0761	(0.0259 from target)
# 15-19: 0.0817	(0.0303 from target)
# 20-24: 0.0493	(-0.0103 from target)
# 25-29: 0.0641	(-0.0056 from target)
# 30-34: 0.0636	(-0.0119 from target)
# 35-39: 0.0638	(-0.0087 from target)
# 40-44: 0.0594	(-0.0140 from target)
# 45-49: 0.0643	(-0.0110 from target)
# 5-9: 0.0745	(0.0246 from target)
# 50-54: 0.0588	(-0.0129 from target)
# 55-59: 0.0623	(-0.0125 from target)
# 60-64: 0.0577	(-0.0132 from target)
# 65-69: 0.0569	(-0.0021 from target)
# 70-74: 0.0453	(-0.0002 from target)
# 75-79: 0.0232	(0.0004 from target)
# 80-84: 0.0168	(-0.0011 from target)
# 85-89: 0.0095	(0.0001 from target)
# 90: 0.0043	(-0.0012 from target)
#
# Generated household size distribution:
# 1: 0.1632	(0.0069 from target)
# 2: 0.2400	(0.0018 from target)
# 3: 0.2028	(-0.0111 from target)
# 4: 0.2019	(0.0012 from target)
# 5: 0.1146	(-0.0011 from target)
# 6: 0.0774	(0.0023 from target)
# Num households: 3229
# mean household size: 3.1065084501977704
#
# Generating graph for 0-9...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 10-19...
# GENERATING WITH FARZ GENERATOR
# /Users/donghan37/Documents/Final Year Project/demo/.venv/lib/python3.8/site-packages/networkx/linalg/graphmatrix.py:187: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return adjacency_matrix(G, nodelist, dtype, weight)
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 20-64...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 65+...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# /Users/donghan37/Documents/Final Year Project/demo/lib/models.py:673: RuntimeWarning: invalid value encountered in divide
#   self.delta_Q = numpy.log(self.degree_Q) / numpy.log(numpy.mean(self.degree_Q)) if self.parameters[
# [INTERVENTIONS @ t = 0.90 (7 (0.07%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [UPDATE @ t = 1 (p-> 0.001)]
# [INTERVENTIONS @ t = 1.06 (7 (0.07%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 3.77 (8 (0.08%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 5.61 (9 (0.09%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 6.48 (8 (0.08%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [NEW EXPOSURE @ t = 7.39 (1 exposed)]
# [INTERVENTIONS @ t = 7.39 (8 (0.08%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 8.50 (10 (0.10%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 9.24 (11 (0.11%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 10.26 (13 (0.13%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 11.41 (12 (0.12%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 12.24 (12 (0.12%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 13.54 (14 (0.14%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 14.26 (16 (0.16%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 15.34 (17 (0.17%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 16.25 (19 (0.19%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 17.54 (19 (0.19%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 18.36 (18 (0.18%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 19.08 (18 (0.18%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 20.32 (18 (0.18%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 21.14 (19 (0.19%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 22.03 (19 (0.19%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 23.24 (23 (0.23%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 24.02 (25 (0.25%) infected)]
# 	3	tested due to symptoms  [+ 1 positive (33.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 1 positive (33.33 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 25.03 (30 (0.30%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 26.04 (30 (0.30%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 27.13 (30 (0.30%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 28.02 (31 (0.31%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 29.08 (32 (0.32%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 30.01 (33 (0.33%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 31.06 (36 (0.36%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 32.23 (36 (0.36%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 33.06 (35 (0.35%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 34.14 (34 (0.34%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 35.01 (33 (0.33%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 36.21 (36 (0.36%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 37.03 (37 (0.37%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 38.30 (37 (0.37%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 39.14 (41 (0.41%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 40.09 (44 (0.44%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 41.26 (48 (0.48%) infected)]
# 	4	tested due to symptoms  [+ 4 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 4 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 42.06 (51 (0.51%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 43.24 (50 (0.50%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 44.09 (52 (0.52%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 45.02 (57 (0.57%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 46.02 (60 (0.60%) infected)]
# 	4	tested due to symptoms  [+ 2 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 2 positive (50.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 47.16 (60 (0.60%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [NEW EXPOSURE @ t = 48.04 (1 exposed)]
# [INTERVENTIONS @ t = 48.04 (67 (0.67%) infected)]
# 	4	tested due to symptoms  [+ 4 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 4 positive (100.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [INTERVENTIONS @ t = 49.21 (72 (0.72%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 50.01 (72 (0.72%) infected)]
# 	4	tested due to symptoms  [+ 4 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 4 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 51.14 (75 (0.75%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [INTERVENTIONS @ t = 52.10 (80 (0.80%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	13 entered isolation
# [INTERVENTIONS @ t = 53.01 (81 (0.81%) infected)]
# 	4	tested due to symptoms  [+ 2 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 2 positive (50.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [INTERVENTIONS @ t = 54.06 (89 (0.89%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [NEW EXPOSURE @ t = 55.00 (1 exposed)]
# [INTERVENTIONS @ t = 55.00 (94 (0.94%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 56.02 (98 (0.98%) infected)]
# 	9	tested due to symptoms  [+ 6 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	9	tested TOTAL            [+ 6 positive (66.67 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 57.00 (102 (1.02%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 58.06 (103 (1.03%) infected)]
# 	6	tested due to symptoms  [+ 3 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 3 positive (50.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	17 entered isolation
# [INTERVENTIONS @ t = 59.02 (110 (1.10%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	14 entered isolation
# [INTERVENTIONS @ t = 60.02 (115 (1.15%) infected)]
# 	6	tested due to symptoms  [+ 5 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 5 positive (83.33 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [NEW EXPOSURE @ t = 61.01 (1 exposed)]
# [INTERVENTIONS @ t = 61.01 (124 (1.24%) infected)]
# 	7	tested due to symptoms  [+ 7 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	7	tested TOTAL            [+ 7 positive (100.00 %) +]
# 	10 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 62.00 (127 (1.27%) infected)]
# 	10	tested due to symptoms  [+ 7 positive (70.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 7 positive (70.00 %) +]
# 	14 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	15 entered isolation
# [INTERVENTIONS @ t = 63.02 (130 (1.30%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	21 entered isolation
# [INTERVENTIONS @ t = 64.01 (137 (1.37%) infected)]
# 	10	tested due to symptoms  [+ 7 positive (70.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 7 positive (70.00 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	16 entered isolation
# [INTERVENTIONS @ t = 65.01 (148 (1.48%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	14 entered isolation
# [INTERVENTIONS @ t = 66.02 (155 (1.55%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	18 entered isolation
# [INTERVENTIONS @ t = 67.00 (162 (1.62%) infected)]
# 	14	tested due to symptoms  [+ 11 positive (78.57 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	14	tested TOTAL            [+ 11 positive (78.57 %) +]
# 	15 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 68.02 (167 (1.67%) infected)]
# 	8	tested due to symptoms  [+ 7 positive (87.50 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	8	tested TOTAL            [+ 7 positive (87.50 %) +]
# 	15 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	18 entered isolation
# [INTERVENTIONS @ t = 69.02 (174 (1.74%) infected)]
# 	4	tested due to symptoms  [+ 4 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 4 positive (100.00 %) +]
# 	12 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	26 entered isolation
# [NEW EXPOSURE @ t = 70.01 (1 exposed)]
# [INTERVENTIONS @ t = 70.01 (175 (1.75%) infected)]
# 	9	tested due to symptoms  [+ 7 positive (77.78 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	9	tested TOTAL            [+ 7 positive (77.78 %) +]
# 	12 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	19 entered isolation
# [INTERVENTIONS @ t = 71.00 (188 (1.88%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	13 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	16 entered isolation
# [INTERVENTIONS @ t = 72.02 (194 (1.94%) infected)]
# 	8	tested due to symptoms  [+ 8 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	8	tested TOTAL            [+ 8 positive (100.00 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	8 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	20 entered isolation
# [INTERVENTIONS @ t = 73.00 (204 (2.04%) infected)]
# 	16	tested due to symptoms  [+ 11 positive (68.75 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	16	tested TOTAL            [+ 11 positive (68.75 %) +]
# 	16 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	15 entered isolation
# [INTERVENTIONS @ t = 74.00 (211 (2.11%) infected)]
# 	17	tested due to symptoms  [+ 16 positive (94.12 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 16 positive (94.12 %) +]
# 	24 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	24 entered isolation
# [INTERVENTIONS @ t = 75.03 (223 (2.23%) infected)]
# 	11	tested due to symptoms  [+ 8 positive (72.73 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	11	tested TOTAL            [+ 8 positive (72.73 %) +]
# 	27 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	8 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	35 entered isolation
# [INTERVENTIONS @ t = 76.01 (232 (2.32%) infected)]
# 	13	tested due to symptoms  [+ 12 positive (92.31 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	13	tested TOTAL            [+ 12 positive (92.31 %) +]
# 	24 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	43 entered isolation
# [INTERVENTIONS @ t = 77.02 (238 (2.38%) infected)]
# 	14	tested due to symptoms  [+ 12 positive (85.71 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	14	tested TOTAL            [+ 12 positive (85.71 %) +]
# 	22 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	32 entered isolation
# [INTERVENTIONS @ t = 78.00 (247 (2.47%) infected)]
# 	9	tested due to symptoms  [+ 7 positive (77.78 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	9	tested TOTAL            [+ 7 positive (77.78 %) +]
# 	14 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	34 entered isolation
# [INTERVENTIONS @ t = 79.00 (267 (2.67%) infected)]
# 	10	tested due to symptoms  [+ 8 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 8 positive (80.00 %) +]
# 	18 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	8 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	26 entered isolation
# [INTERVENTIONS @ t = 80.02 (285 (2.85%) infected)]
# 	8	tested due to symptoms  [+ 7 positive (87.50 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	8	tested TOTAL            [+ 7 positive (87.50 %) +]
# 	16 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	25 entered isolation
# [INTERVENTIONS @ t = 81.01 (298 (2.98%) infected)]
# 	15	tested due to symptoms  [+ 12 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 12 positive (80.00 %) +]
# 	23 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	24 entered isolation
# [INTERVENTIONS @ t = 82.03 (312 (3.12%) infected)]
# 	17	tested due to symptoms  [+ 14 positive (82.35 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 14 positive (82.35 %) +]
# 	24 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	14 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	30 entered isolation
# [INTERVENTIONS @ t = 83.00 (324 (3.24%) infected)]
# 	17	tested due to symptoms  [+ 15 positive (88.24 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 15 positive (88.24 %) +]
# 	21 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	36 entered isolation
# [INTERVENTIONS @ t = 84.03 (342 (3.42%) infected)]
# 	22	tested due to symptoms  [+ 18 positive (81.82 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	22	tested TOTAL            [+ 18 positive (81.82 %) +]
# 	33 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	35 entered isolation
# [INTERVENTIONS @ t = 85.01 (353 (3.53%) infected)]
# 	15	tested due to symptoms  [+ 11 positive (73.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 11 positive (73.33 %) +]
# 	31 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	48 entered isolation
# [NEW EXPOSURE @ t = 86.01 (1 exposed)]
# [INTERVENTIONS @ t = 86.01 (370 (3.70%) infected)]
# 	19	tested due to symptoms  [+ 16 positive (84.21 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 16 positive (84.21 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	49 entered isolation
# [INTERVENTIONS @ t = 87.01 (393 (3.93%) infected)]
# 	22	tested due to symptoms  [+ 17 positive (77.27 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	22	tested TOTAL            [+ 17 positive (77.27 %) +]
# 	37 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [INTERVENTIONS @ t = 88.02 (407 (4.07%) infected)]
# 	26	tested due to symptoms  [+ 23 positive (88.46 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	26	tested TOTAL            [+ 23 positive (88.46 %) +]
# 	43 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	23 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	53 entered isolation
# [INTERVENTIONS @ t = 89.02 (429 (4.29%) infected)]
# 	13	tested due to symptoms  [+ 11 positive (84.62 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	13	tested TOTAL            [+ 11 positive (84.62 %) +]
# 	32 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	60 entered isolation
# [INTERVENTIONS @ t = 90.00 (448 (4.48%) infected)]
# 	25	tested due to symptoms  [+ 19 positive (76.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	25	tested TOTAL            [+ 19 positive (76.00 %) +]
# 	35 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	55 entered isolation
# [INTERVENTIONS @ t = 91.00 (455 (4.55%) infected)]
# 	18	tested due to symptoms  [+ 15 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	18	tested TOTAL            [+ 15 positive (83.33 %) +]
# 	42 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	46 entered isolation
# [INTERVENTIONS @ t = 92.02 (462 (4.62%) infected)]
# 	26	tested due to symptoms  [+ 22 positive (84.62 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	26	tested TOTAL            [+ 22 positive (84.62 %) +]
# 	44 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	22 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	61 entered isolation
# [INTERVENTIONS @ t = 93.00 (476 (4.76%) infected)]
# 	27	tested due to symptoms  [+ 24 positive (88.89 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	27	tested TOTAL            [+ 24 positive (88.89 %) +]
# 	48 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	24 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	59 entered isolation
# [INTERVENTIONS @ t = 94.01 (486 (4.86%) infected)]
# 	23	tested due to symptoms  [+ 20 positive (86.96 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	23	tested TOTAL            [+ 20 positive (86.96 %) +]
# 	40 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	20 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	70 entered isolation
# [INTERVENTIONS @ t = 95.01 (499 (4.99%) infected)]
# 	28	tested due to symptoms  [+ 25 positive (89.29 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	28	tested TOTAL            [+ 25 positive (89.29 %) +]
# 	34 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	25 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	64 entered isolation
# [INTERVENTIONS @ t = 96.00 (508 (5.08%) infected)]
# 	34	tested due to symptoms  [+ 28 positive (82.35 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	34	tested TOTAL            [+ 28 positive (82.35 %) +]
# 	47 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	28 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	54 entered isolation
# [INTERVENTIONS @ t = 97.02 (252 (2.52%) infected)]
# 	15	tested due to symptoms  [+ 13 positive (86.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 13 positive (86.67 %) +]
# 	24 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	72 entered isolation
# [INTERVENTIONS @ t = 98.01 (265 (2.65%) infected)]
# 	11	tested due to symptoms  [+ 11 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	11	tested TOTAL            [+ 11 positive (100.00 %) +]
# 	22 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	52 entered isolation
# [INTERVENTIONS @ t = 99.00 (281 (2.81%) infected)]
# 	15	tested due to symptoms  [+ 14 positive (93.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 14 positive (93.33 %) +]
# 	21 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	14 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	35 entered isolation
# [NEW EXPOSURE @ t = 100.05 (1 exposed)]
# [INTERVENTIONS @ t = 100.05 (294 (2.94%) infected)]
# 	18	tested due to symptoms  [+ 15 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	18	tested TOTAL            [+ 15 positive (83.33 %) +]
# 	29 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	32 entered isolation
# [NEW EXPOSURE @ t = 101.01 (1 exposed)]
# [INTERVENTIONS @ t = 101.01 (303 (3.03%) infected)]
# 	16	tested due to symptoms  [+ 11 positive (68.75 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	16	tested TOTAL            [+ 11 positive (68.75 %) +]
# 	31 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	43 entered isolation
# [INTERVENTIONS @ t = 102.03 (318 (3.18%) infected)]
# 	19	tested due to symptoms  [+ 18 positive (94.74 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 18 positive (94.74 %) +]
# 	33 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	46 entered isolation
# [INTERVENTIONS @ t = 103.02 (330 (3.30%) infected)]
# 	24	tested due to symptoms  [+ 19 positive (79.17 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	24	tested TOTAL            [+ 19 positive (79.17 %) +]
# 	41 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	44 entered isolation
# [INTERVENTIONS @ t = 104.00 (345 (3.45%) infected)]
# 	14	tested due to symptoms  [+ 12 positive (85.71 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	14	tested TOTAL            [+ 12 positive (85.71 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	59 entered isolation
# [NEW EXPOSURE @ t = 105.00 (1 exposed)]
# [INTERVENTIONS @ t = 105.00 (349 (3.49%) infected)]
# 	17	tested due to symptoms  [+ 12 positive (70.59 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 12 positive (70.59 %) +]
# 	22 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	47 entered isolation
# [INTERVENTIONS @ t = 106.02 (351 (3.51%) infected)]
# 	13	tested due to symptoms  [+ 9 positive (69.23 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	13	tested TOTAL            [+ 9 positive (69.23 %) +]
# 	26 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	34 entered isolation
# [INTERVENTIONS @ t = 107.01 (354 (3.54%) infected)]
# 	20	tested due to symptoms  [+ 19 positive (95.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	20	tested TOTAL            [+ 19 positive (95.00 %) +]
# 	27 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	38 entered isolation
# [INTERVENTIONS @ t = 108.02 (364 (3.64%) infected)]
# 	19	tested due to symptoms  [+ 11 positive (57.89 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 11 positive (57.89 %) +]
# 	34 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	36 entered isolation
# [INTERVENTIONS @ t = 109.01 (377 (3.77%) infected)]
# 	13	tested due to symptoms  [+ 9 positive (69.23 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	13	tested TOTAL            [+ 9 positive (69.23 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	53 entered isolation
# [INTERVENTIONS @ t = 110.00 (403 (4.03%) infected)]
# 	24	tested due to symptoms  [+ 18 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	24	tested TOTAL            [+ 18 positive (75.00 %) +]
# 	33 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [INTERVENTIONS @ t = 111.03 (413 (4.13%) infected)]
# 	22	tested due to symptoms  [+ 19 positive (86.36 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	22	tested TOTAL            [+ 19 positive (86.36 %) +]
# 	38 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	42 entered isolation
# [INTERVENTIONS @ t = 112.00 (418 (4.18%) infected)]
# 	25	tested due to symptoms  [+ 21 positive (84.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	25	tested TOTAL            [+ 21 positive (84.00 %) +]
# 	30 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	21 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	56 entered isolation
# [INTERVENTIONS @ t = 113.01 (427 (4.27%) infected)]
# 	23	tested due to symptoms  [+ 20 positive (86.96 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	23	tested TOTAL            [+ 20 positive (86.96 %) +]
# 	37 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	20 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	49 entered isolation
# [INTERVENTIONS @ t = 114.00 (446 (4.46%) infected)]
# 	22	tested due to symptoms  [+ 19 positive (86.36 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	22	tested TOTAL            [+ 19 positive (86.36 %) +]
# 	38 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	58 entered isolation
# [INTERVENTIONS @ t = 115.03 (243 (2.43%) infected)]
# 	11	tested due to symptoms  [+ 9 positive (81.82 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	11	tested TOTAL            [+ 9 positive (81.82 %) +]
# 	20 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	58 entered isolation
# [INTERVENTIONS @ t = 116.00 (254 (2.54%) infected)]
# 	10	tested due to symptoms  [+ 7 positive (70.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 7 positive (70.00 %) +]
# 	16 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [INTERVENTIONS @ t = 117.01 (270 (2.70%) infected)]
# 	7	tested due to symptoms  [+ 7 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	7	tested TOTAL            [+ 7 positive (100.00 %) +]
# 	13 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	25 entered isolation
# [INTERVENTIONS @ t = 118.01 (279 (2.79%) infected)]
# 	16	tested due to symptoms  [+ 13 positive (81.25 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	16	tested TOTAL            [+ 13 positive (81.25 %) +]
# 	24 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	20 entered isolation
# [INTERVENTIONS @ t = 119.00 (302 (3.02%) infected)]
# 	17	tested due to symptoms  [+ 15 positive (88.24 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 15 positive (88.24 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	31 entered isolation
# [NEW EXPOSURE @ t = 120.02 (1 exposed)]
# [INTERVENTIONS @ t = 120.02 (314 (3.14%) infected)]
# 	11	tested due to symptoms  [+ 8 positive (72.73 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	11	tested TOTAL            [+ 8 positive (72.73 %) +]
# 	25 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	8 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	41 entered isolation
# <AxesSubplot:xlabel='days', ylabel='number of individuals'>

# %%
SEIR_network = SEIRNetwork()
simulator = Simulator(SEIR_network)
simulator.generate_simulation(T = 120)
simulator.set_imported_case(time=1, average_introductions_per_day=1.0)
# simulator.set_social_distancing(time=1,global_rate=0.001)
simulator.run()
from matplotlib.pyplot import figure

figure(figsize=(15,5))
simulator.model.figure_infections(
    plot_S=False,
    plot_E=False,
    plot_I_pre=False,
    plot_I_sym='stacked',
    plot_Q_sym='stacked',
    plot_Q_pre=False,
    plot_Q_asym=False,
    plot_I_asym=False,
    show=False,
    combine_Q_infected=False,
    plot_percentages=False,
    scaled=True
)
# Out:
# Household size does not match number of age brackets assigned. u20_o65_gt1
# Generated overall age distribution:
# 0-4: 0.0701	(0.0253 from target)
# 10-14: 0.0786	(0.0284 from target)
# 15-19: 0.0770	(0.0256 from target)
# 20-24: 0.0515	(-0.0081 from target)
# 25-29: 0.0583	(-0.0114 from target)
# 30-34: 0.0663	(-0.0092 from target)
# 35-39: 0.0640	(-0.0085 from target)
# 40-44: 0.0628	(-0.0106 from target)
# 45-49: 0.0632	(-0.0121 from target)
# 5-9: 0.0750	(0.0251 from target)
# 50-54: 0.0563	(-0.0154 from target)
# 55-59: 0.0649	(-0.0099 from target)
# 60-64: 0.0624	(-0.0085 from target)
# 65-69: 0.0561	(-0.0029 from target)
# 70-74: 0.0429	(-0.0026 from target)
# 75-79: 0.0211	(-0.0017 from target)
# 80-84: 0.0152	(-0.0027 from target)
# 85-89: 0.0093	(-0.0001 from target)
# 90: 0.0050	(-0.0005 from target)
#
# Generated household size distribution:
# 1: 0.1601	(0.0037 from target)
# 2: 0.2307	(-0.0075 from target)
# 3: 0.2183	(0.0043 from target)
# 4: 0.2074	(0.0067 from target)
# 5: 0.1115	(-0.0043 from target)
# 6: 0.0721	(-0.0029 from target)
# Num households: 3230
# mean household size: 3.1065084501977704
#
# Generating graph for 0-9...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# /Users/donghan37/Documents/Final Year Project/demo/.venv/lib/python3.8/site-packages/networkx/linalg/graphmatrix.py:187: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return adjacency_matrix(G, nodelist, dtype, weight)
# Generating graph for 10-19...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 20-64...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 65+...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# /Users/donghan37/Documents/Final Year Project/demo/lib/models.py:673: RuntimeWarning: invalid value encountered in divide
#   self.delta_Q = numpy.log(self.degree_Q) / numpy.log(numpy.mean(self.degree_Q)) if self.parameters[
# [INTERVENTIONS @ t = 0.15 (7 (0.07%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 1.02 (8 (0.08%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 2.00 (9 (0.09%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 3.14 (9 (0.09%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 4.02 (10 (0.10%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 5.52 (11 (0.11%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 6.13 (11 (0.11%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 7.13 (12 (0.12%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [NEW EXPOSURE @ t = 8.16 (1 exposed)]
# [INTERVENTIONS @ t = 8.16 (12 (0.12%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 9.19 (13 (0.13%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 10.26 (14 (0.14%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 11.24 (17 (0.17%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 12.04 (17 (0.17%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 13.04 (18 (0.18%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 14.29 (19 (0.19%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 15.22 (19 (0.19%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 16.20 (20 (0.20%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [NEW EXPOSURE @ t = 17.34 (1 exposed)]
# [INTERVENTIONS @ t = 17.34 (24 (0.24%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 18.04 (29 (0.29%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 19.00 (34 (0.34%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 20.02 (41 (0.41%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 21.07 (42 (0.42%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 22.04 (44 (0.44%) infected)]
# 	6	tested due to symptoms  [+ 4 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 4 positive (66.67 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 23.04 (51 (0.51%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 24.03 (60 (0.60%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	13 entered isolation
# [INTERVENTIONS @ t = 25.08 (60 (0.60%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [NEW EXPOSURE @ t = 26.02 (1 exposed)]
# [INTERVENTIONS @ t = 26.02 (65 (0.65%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 27.00 (70 (0.70%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 28.04 (79 (0.79%) infected)]
# 	7	tested due to symptoms  [+ 5 positive (71.43 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	7	tested TOTAL            [+ 5 positive (71.43 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 29.00 (89 (0.89%) infected)]
# 	6	tested due to symptoms  [+ 6 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 6 positive (100.00 %) +]
# 	10 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	16 entered isolation
# [INTERVENTIONS @ t = 30.01 (97 (0.97%) infected)]
# 	4	tested due to symptoms  [+ 4 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 4 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	15 entered isolation
# [INTERVENTIONS @ t = 31.05 (112 (1.12%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 32.00 (131 (1.31%) infected)]
# 	9	tested due to symptoms  [+ 6 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	9	tested TOTAL            [+ 6 positive (66.67 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 33.01 (147 (1.47%) infected)]
# 	8	tested due to symptoms  [+ 5 positive (62.50 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	8	tested TOTAL            [+ 5 positive (62.50 %) +]
# 	12 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [INTERVENTIONS @ t = 34.01 (161 (1.61%) infected)]
# 	6	tested due to symptoms  [+ 6 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 6 positive (100.00 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	18 entered isolation
# [INTERVENTIONS @ t = 35.00 (173 (1.73%) infected)]
# 	8	tested due to symptoms  [+ 6 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	8	tested TOTAL            [+ 6 positive (75.00 %) +]
# 	10 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	16 entered isolation
# [INTERVENTIONS @ t = 36.02 (185 (1.85%) infected)]
# 	11	tested due to symptoms  [+ 10 positive (90.91 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	11	tested TOTAL            [+ 10 positive (90.91 %) +]
# 	12 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	10 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	16 entered isolation
# [NEW EXPOSURE @ t = 37.01 (1 exposed)]
# [INTERVENTIONS @ t = 37.01 (204 (2.04%) infected)]
# 	6	tested due to symptoms  [+ 5 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 5 positive (83.33 %) +]
# 	13 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	18 entered isolation
# [INTERVENTIONS @ t = 38.01 (239 (2.39%) infected)]
# 	17	tested due to symptoms  [+ 11 positive (64.71 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 11 positive (64.71 %) +]
# 	17 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	23 entered isolation
# [INTERVENTIONS @ t = 39.00 (275 (2.75%) infected)]
# 	14	tested due to symptoms  [+ 9 positive (64.29 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	14	tested TOTAL            [+ 9 positive (64.29 %) +]
# 	24 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	22 entered isolation
# [INTERVENTIONS @ t = 40.02 (294 (2.94%) infected)]
# 	21	tested due to symptoms  [+ 18 positive (85.71 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	21	tested TOTAL            [+ 18 positive (85.71 %) +]
# 	30 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	35 entered isolation
# [INTERVENTIONS @ t = 41.02 (321 (3.21%) infected)]
# 	15	tested due to symptoms  [+ 12 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 12 positive (80.00 %) +]
# 	31 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [INTERVENTIONS @ t = 42.01 (352 (3.52%) infected)]
# 	13	tested due to symptoms  [+ 11 positive (84.62 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	13	tested TOTAL            [+ 11 positive (84.62 %) +]
# 	22 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	49 entered isolation
# [INTERVENTIONS @ t = 43.00 (386 (3.86%) infected)]
# 	27	tested due to symptoms  [+ 23 positive (85.19 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	27	tested TOTAL            [+ 23 positive (85.19 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	23 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	34 entered isolation
# [INTERVENTIONS @ t = 44.00 (429 (4.29%) infected)]
# 	16	tested due to symptoms  [+ 13 positive (81.25 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	16	tested TOTAL            [+ 13 positive (81.25 %) +]
# 	34 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [INTERVENTIONS @ t = 45.00 (466 (4.66%) infected)]
# 	24	tested due to symptoms  [+ 20 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	24	tested TOTAL            [+ 20 positive (83.33 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	20 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	57 entered isolation
# [INTERVENTIONS @ t = 46.01 (517 (5.17%) infected)]
# 	33	tested due to symptoms  [+ 28 positive (84.85 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	33	tested TOTAL            [+ 28 positive (84.85 %) +]
# 	44 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	28 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	41 entered isolation
# [INTERVENTIONS @ t = 47.01 (585 (5.85%) infected)]
# 	36	tested due to symptoms  [+ 30 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	36	tested TOTAL            [+ 30 positive (83.33 %) +]
# 	58 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	30 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	64 entered isolation
# [INTERVENTIONS @ t = 48.00 (618 (6.18%) infected)]
# 	23	tested due to symptoms  [+ 16 positive (69.57 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	23	tested TOTAL            [+ 16 positive (69.57 %) +]
# 	42 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	86 entered isolation
# [INTERVENTIONS @ t = 49.01 (671 (6.71%) infected)]
# 	33	tested due to symptoms  [+ 28 positive (84.85 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	33	tested TOTAL            [+ 28 positive (84.85 %) +]
# 	45 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	28 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	72 entered isolation
# [INTERVENTIONS @ t = 50.01 (724 (7.24%) infected)]
# 	34	tested due to symptoms  [+ 24 positive (70.59 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	34	tested TOTAL            [+ 24 positive (70.59 %) +]
# 	54 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	24 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	61 entered isolation
# [INTERVENTIONS @ t = 51.01 (406 (4.06%) infected)]
# 	23	tested due to symptoms  [+ 17 positive (73.91 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	23	tested TOTAL            [+ 17 positive (73.91 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	82 entered isolation
# [INTERVENTIONS @ t = 52.01 (446 (4.46%) infected)]
# 	28	tested due to symptoms  [+ 18 positive (64.29 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	28	tested TOTAL            [+ 18 positive (64.29 %) +]
# 	40 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	52 entered isolation
# [INTERVENTIONS @ t = 53.00 (496 (4.96%) infected)]
# 	24	tested due to symptoms  [+ 21 positive (87.50 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	24	tested TOTAL            [+ 21 positive (87.50 %) +]
# 	48 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	21 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	57 entered isolation
# [NEW EXPOSURE @ t = 54.01 (1 exposed)]
# [INTERVENTIONS @ t = 54.01 (538 (5.38%) infected)]
# 	31	tested due to symptoms  [+ 24 positive (77.42 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	31	tested TOTAL            [+ 24 positive (77.42 %) +]
# 	47 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	24 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	66 entered isolation
# [INTERVENTIONS @ t = 55.01 (600 (6.00%) infected)]
# 	33	tested due to symptoms  [+ 28 positive (84.85 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	33	tested TOTAL            [+ 28 positive (84.85 %) +]
# 	53 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	28 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	68 entered isolation
# [INTERVENTIONS @ t = 56.01 (659 (6.59%) infected)]
# 	32	tested due to symptoms  [+ 26 positive (81.25 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	32	tested TOTAL            [+ 26 positive (81.25 %) +]
# 	53 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	26 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	77 entered isolation
# [INTERVENTIONS @ t = 57.00 (704 (7.04%) infected)]
# 	32	tested due to symptoms  [+ 25 positive (78.12 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	32	tested TOTAL            [+ 25 positive (78.12 %) +]
# 	44 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	25 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	81 entered isolation
# [INTERVENTIONS @ t = 58.00 (388 (3.88%) infected)]
# 	15	tested due to symptoms  [+ 11 positive (73.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 11 positive (73.33 %) +]
# 	25 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	70 entered isolation
# [INTERVENTIONS @ t = 59.00 (445 (4.45%) infected)]
# 	18	tested due to symptoms  [+ 16 positive (88.89 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	18	tested TOTAL            [+ 16 positive (88.89 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	50 entered isolation
# [INTERVENTIONS @ t = 60.00 (497 (4.97%) infected)]
# 	25	tested due to symptoms  [+ 20 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	25	tested TOTAL            [+ 20 positive (80.00 %) +]
# 	32 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	20 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [INTERVENTIONS @ t = 61.00 (556 (5.56%) infected)]
# 	33	tested due to symptoms  [+ 31 positive (93.94 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	33	tested TOTAL            [+ 31 positive (93.94 %) +]
# 	46 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	31 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	48 entered isolation
# [INTERVENTIONS @ t = 62.02 (610 (6.10%) infected)]
# 	33	tested due to symptoms  [+ 23 positive (69.70 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	33	tested TOTAL            [+ 23 positive (69.70 %) +]
# 	56 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	23 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	66 entered isolation
# [INTERVENTIONS @ t = 63.00 (663 (6.63%) infected)]
# 	32	tested due to symptoms  [+ 23 positive (71.88 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	32	tested TOTAL            [+ 23 positive (71.88 %) +]
# 	49 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	23 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	87 entered isolation
# [INTERVENTIONS @ t = 64.00 (710 (7.10%) infected)]
# 	39	tested due to symptoms  [+ 30 positive (76.92 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	39	tested TOTAL            [+ 30 positive (76.92 %) +]
# 	61 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	30 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	72 entered isolation
# [INTERVENTIONS @ t = 65.01 (401 (4.01%) infected)]
# 	27	tested due to symptoms  [+ 19 positive (70.37 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	27	tested TOTAL            [+ 19 positive (70.37 %) +]
# 	44 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	84 entered isolation
# [INTERVENTIONS @ t = 66.01 (436 (4.36%) infected)]
# 	30	tested due to symptoms  [+ 21 positive (70.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	30	tested TOTAL            [+ 21 positive (70.00 %) +]
# 	49 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	21 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	74 entered isolation
# [INTERVENTIONS @ t = 67.01 (476 (4.76%) infected)]
# 	19	tested due to symptoms  [+ 14 positive (73.68 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 14 positive (73.68 %) +]
# 	41 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	14 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	68 entered isolation
# [INTERVENTIONS @ t = 68.01 (528 (5.28%) infected)]
# 	24	tested due to symptoms  [+ 19 positive (79.17 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	24	tested TOTAL            [+ 19 positive (79.17 %) +]
# 	33 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	62 entered isolation
# [INTERVENTIONS @ t = 69.01 (565 (5.65%) infected)]
# 	24	tested due to symptoms  [+ 16 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	24	tested TOTAL            [+ 16 positive (66.67 %) +]
# 	39 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	47 entered isolation
# [INTERVENTIONS @ t = 70.01 (612 (6.12%) infected)]
# 	29	tested due to symptoms  [+ 24 positive (82.76 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	29	tested TOTAL            [+ 24 positive (82.76 %) +]
# 	46 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	24 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	58 entered isolation
# [INTERVENTIONS @ t = 71.00 (664 (6.64%) infected)]
# 	29	tested due to symptoms  [+ 27 positive (93.10 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	29	tested TOTAL            [+ 27 positive (93.10 %) +]
# 	53 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	27 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	62 entered isolation
# [NEW EXPOSURE @ t = 72.00 (1 exposed)]
# [INTERVENTIONS @ t = 72.00 (721 (7.21%) infected)]
# 	34	tested due to symptoms  [+ 26 positive (76.47 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	34	tested TOTAL            [+ 26 positive (76.47 %) +]
# 	51 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	26 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	77 entered isolation
# [INTERVENTIONS @ t = 73.01 (396 (3.96%) infected)]
# 	22	tested due to symptoms  [+ 17 positive (77.27 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	22	tested TOTAL            [+ 17 positive (77.27 %) +]
# 	38 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	78 entered isolation
# [INTERVENTIONS @ t = 74.01 (438 (4.38%) infected)]
# 	20	tested due to symptoms  [+ 18 positive (90.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	20	tested TOTAL            [+ 18 positive (90.00 %) +]
# 	34 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	64 entered isolation
# [INTERVENTIONS @ t = 75.01 (480 (4.80%) infected)]
# 	15	tested due to symptoms  [+ 11 positive (73.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 11 positive (73.33 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	51 entered isolation
# [INTERVENTIONS @ t = 76.02 (524 (5.24%) infected)]
# 	26	tested due to symptoms  [+ 18 positive (69.23 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	26	tested TOTAL            [+ 18 positive (69.23 %) +]
# 	36 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	46 entered isolation
# [INTERVENTIONS @ t = 77.00 (564 (5.64%) infected)]
# 	20	tested due to symptoms  [+ 17 positive (85.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	20	tested TOTAL            [+ 17 positive (85.00 %) +]
# 	34 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	47 entered isolation
# [INTERVENTIONS @ t = 78.01 (611 (6.11%) infected)]
# 	33	tested due to symptoms  [+ 29 positive (87.88 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	33	tested TOTAL            [+ 29 positive (87.88 %) +]
# 	48 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	29 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	52 entered isolation
# [NEW EXPOSURE @ t = 79.00 (2 exposed)]
# [INTERVENTIONS @ t = 79.00 (668 (6.68%) infected)]
# 	36	tested due to symptoms  [+ 28 positive (77.78 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	36	tested TOTAL            [+ 28 positive (77.78 %) +]
# 	67 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	28 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	65 entered isolation
# [INTERVENTIONS @ t = 80.00 (735 (7.35%) infected)]
# 	29	tested due to symptoms  [+ 26 positive (89.66 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	29	tested TOTAL            [+ 26 positive (89.66 %) +]
# 	63 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	26 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	96 entered isolation
# [INTERVENTIONS @ t = 81.01 (389 (3.89%) infected)]
# 	24	tested due to symptoms  [+ 19 positive (79.17 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	24	tested TOTAL            [+ 19 positive (79.17 %) +]
# 	44 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	91 entered isolation
# [NEW EXPOSURE @ t = 82.00 (1 exposed)]
# [INTERVENTIONS @ t = 82.00 (422 (4.22%) infected)]
# 	15	tested due to symptoms  [+ 11 positive (73.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 11 positive (73.33 %) +]
# 	37 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	70 entered isolation
# [INTERVENTIONS @ t = 83.00 (463 (4.63%) infected)]
# 	19	tested due to symptoms  [+ 13 positive (68.42 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 13 positive (68.42 %) +]
# 	34 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	56 entered isolation
# [INTERVENTIONS @ t = 84.00 (498 (4.98%) infected)]
# 	32	tested due to symptoms  [+ 24 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	32	tested TOTAL            [+ 24 positive (75.00 %) +]
# 	45 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	24 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	45 entered isolation
# [INTERVENTIONS @ t = 85.01 (529 (5.29%) infected)]
# 	31	tested due to symptoms  [+ 24 positive (77.42 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	31	tested TOTAL            [+ 24 positive (77.42 %) +]
# 	60 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	24 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	58 entered isolation
# [INTERVENTIONS @ t = 86.01 (574 (5.74%) infected)]
# 	27	tested due to symptoms  [+ 17 positive (62.96 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	27	tested TOTAL            [+ 17 positive (62.96 %) +]
# 	55 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	84 entered isolation
# [NEW EXPOSURE @ t = 87.01 (1 exposed)]
# [INTERVENTIONS @ t = 87.01 (613 (6.13%) infected)]
# 	20	tested due to symptoms  [+ 13 positive (65.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	20	tested TOTAL            [+ 13 positive (65.00 %) +]
# 	35 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	79 entered isolation
# [INTERVENTIONS @ t = 88.01 (665 (6.65%) infected)]
# 	31	tested due to symptoms  [+ 24 positive (77.42 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	31	tested TOTAL            [+ 24 positive (77.42 %) +]
# 	41 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	24 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	52 entered isolation
# [INTERVENTIONS @ t = 89.00 (723 (7.23%) infected)]
# 	34	tested due to symptoms  [+ 27 positive (79.41 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	34	tested TOTAL            [+ 27 positive (79.41 %) +]
# 	53 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	27 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	54 entered isolation
# [INTERVENTIONS @ t = 90.01 (409 (4.09%) infected)]
# 	15	tested due to symptoms  [+ 12 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 12 positive (80.00 %) +]
# 	25 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	77 entered isolation
# [INTERVENTIONS @ t = 91.01 (427 (4.27%) infected)]
# 	19	tested due to symptoms  [+ 15 positive (78.95 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 15 positive (78.95 %) +]
# 	26 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	52 entered isolation
# [INTERVENTIONS @ t = 92.01 (466 (4.66%) infected)]
# 	26	tested due to symptoms  [+ 22 positive (84.62 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	26	tested TOTAL            [+ 22 positive (84.62 %) +]
# 	33 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	22 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	38 entered isolation
# [INTERVENTIONS @ t = 93.01 (512 (5.12%) infected)]
# 	24	tested due to symptoms  [+ 18 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	24	tested TOTAL            [+ 18 positive (75.00 %) +]
# 	39 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	48 entered isolation
# [INTERVENTIONS @ t = 94.00 (543 (5.43%) infected)]
# 	13	tested due to symptoms  [+ 11 positive (84.62 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	13	tested TOTAL            [+ 11 positive (84.62 %) +]
# 	35 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	61 entered isolation
# [INTERVENTIONS @ t = 95.00 (580 (5.80%) infected)]
# 	23	tested due to symptoms  [+ 16 positive (69.57 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	23	tested TOTAL            [+ 16 positive (69.57 %) +]
# 	34 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	53 entered isolation
# [NEW EXPOSURE @ t = 96.00 (1 exposed)]
# [INTERVENTIONS @ t = 96.00 (636 (6.36%) infected)]
# 	31	tested due to symptoms  [+ 26 positive (83.87 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	31	tested TOTAL            [+ 26 positive (83.87 %) +]
# 	47 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	26 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	45 entered isolation
# [INTERVENTIONS @ t = 97.01 (703 (7.03%) infected)]
# 	39	tested due to symptoms  [+ 30 positive (76.92 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	39	tested TOTAL            [+ 30 positive (76.92 %) +]
# 	63 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	30 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	63 entered isolation
# [INTERVENTIONS @ t = 98.01 (386 (3.86%) infected)]
# 	21	tested due to symptoms  [+ 14 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	21	tested TOTAL            [+ 14 positive (66.67 %) +]
# 	38 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	14 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	89 entered isolation
# [INTERVENTIONS @ t = 99.00 (431 (4.31%) infected)]
# 	20	tested due to symptoms  [+ 18 positive (90.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	20	tested TOTAL            [+ 18 positive (90.00 %) +]
# 	38 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	68 entered isolation
# [NEW EXPOSURE @ t = 100.00 (1 exposed)]
# [INTERVENTIONS @ t = 100.00 (474 (4.74%) infected)]
# 	9	tested due to symptoms  [+ 7 positive (77.78 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	9	tested TOTAL            [+ 7 positive (77.78 %) +]
# 	27 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	52 entered isolation
# [INTERVENTIONS @ t = 101.00 (539 (5.39%) infected)]
# 	21	tested due to symptoms  [+ 16 positive (76.19 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	21	tested TOTAL            [+ 16 positive (76.19 %) +]
# 	32 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	45 entered isolation
# [INTERVENTIONS @ t = 102.00 (596 (5.96%) infected)]
# 	34	tested due to symptoms  [+ 29 positive (85.29 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	34	tested TOTAL            [+ 29 positive (85.29 %) +]
# 	55 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	29 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [INTERVENTIONS @ t = 103.01 (646 (6.46%) infected)]
# 	38	tested due to symptoms  [+ 33 positive (86.84 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	38	tested TOTAL            [+ 33 positive (86.84 %) +]
# 	65 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	33 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	71 entered isolation
# [INTERVENTIONS @ t = 104.00 (692 (6.92%) infected)]
# 	32	tested due to symptoms  [+ 24 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	32	tested TOTAL            [+ 24 positive (75.00 %) +]
# 	59 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	24 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	94 entered isolation
# [INTERVENTIONS @ t = 105.00 (388 (3.88%) infected)]
# 	16	tested due to symptoms  [+ 11 positive (68.75 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	16	tested TOTAL            [+ 11 positive (68.75 %) +]
# 	24 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	92 entered isolation
# [INTERVENTIONS @ t = 106.02 (420 (4.20%) infected)]
# 	15	tested due to symptoms  [+ 12 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 12 positive (80.00 %) +]
# 	33 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	48 entered isolation
# [INTERVENTIONS @ t = 107.00 (463 (4.63%) infected)]
# 	17	tested due to symptoms  [+ 13 positive (76.47 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 13 positive (76.47 %) +]
# 	32 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	44 entered isolation
# [INTERVENTIONS @ t = 108.00 (517 (5.17%) infected)]
# 	24	tested due to symptoms  [+ 19 positive (79.17 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	24	tested TOTAL            [+ 19 positive (79.17 %) +]
# 	32 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	44 entered isolation
# [INTERVENTIONS @ t = 109.00 (585 (5.85%) infected)]
# 	34	tested due to symptoms  [+ 29 positive (85.29 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	34	tested TOTAL            [+ 29 positive (85.29 %) +]
# 	47 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	29 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	45 entered isolation
# [INTERVENTIONS @ t = 110.00 (644 (6.44%) infected)]
# 	33	tested due to symptoms  [+ 25 positive (75.76 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	33	tested TOTAL            [+ 25 positive (75.76 %) +]
# 	53 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	25 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	66 entered isolation
# [INTERVENTIONS @ t = 111.00 (713 (7.13%) infected)]
# 	37	tested due to symptoms  [+ 29 positive (78.38 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	37	tested TOTAL            [+ 29 positive (78.38 %) +]
# 	60 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	29 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	82 entered isolation
# [INTERVENTIONS @ t = 112.00 (787 (7.87%) infected)]
# 	30	tested due to symptoms  [+ 20 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	30	tested TOTAL            [+ 20 positive (66.67 %) +]
# 	62 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	20 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	85 entered isolation
# [INTERVENTIONS @ t = 113.01 (844 (8.44%) infected)]
# 	47	tested due to symptoms  [+ 32 positive (68.09 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	47	tested TOTAL            [+ 32 positive (68.09 %) +]
# 	74 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	32 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	91 entered isolation
# [INTERVENTIONS @ t = 114.00 (894 (8.94%) infected)]
# 	34	tested due to symptoms  [+ 29 positive (85.29 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	34	tested TOTAL            [+ 29 positive (85.29 %) +]
# 	76 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	29 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	94 entered isolation
# [INTERVENTIONS @ t = 115.00 (973 (9.73%) infected)]
# 	36	tested due to symptoms  [+ 31 positive (86.11 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	36	tested TOTAL            [+ 31 positive (86.11 %) +]
# 	71 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	31 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	108 entered isolation
# [INTERVENTIONS @ t = 116.00 (1084 (10.84%) infected)]
# 	52	tested due to symptoms  [+ 47 positive (90.38 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	52	tested TOTAL            [+ 47 positive (90.38 %) +]
# 	79 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	47 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	100 entered isolation
# [INTERVENTIONS @ t = 117.01 (1177 (11.77%) infected)]
# 	59	tested due to symptoms  [+ 44 positive (74.58 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	59	tested TOTAL            [+ 44 positive (74.58 %) +]
# 	93 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	44 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	110 entered isolation
# [INTERVENTIONS @ t = 118.00 (1281 (12.81%) infected)]
# 	62	tested due to symptoms  [+ 52 positive (83.87 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	62	tested TOTAL            [+ 52 positive (83.87 %) +]
# 	100 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	52 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	140 entered isolation
# [INTERVENTIONS @ t = 119.00 (1417 (14.17%) infected)]
# 	71	tested due to symptoms  [+ 57 positive (80.28 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	71	tested TOTAL            [+ 57 positive (80.28 %) +]
# 	117 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	57 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	144 entered isolation
# [INTERVENTIONS @ t = 120.00 (1528 (15.28%) infected)]
# 	61	tested due to symptoms  [+ 47 positive (77.05 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	61	tested TOTAL            [+ 47 positive (77.05 %) +]
# 	128 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	47 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	169 entered isolation
# <AxesSubplot:xlabel='days', ylabel='number of individuals'>
