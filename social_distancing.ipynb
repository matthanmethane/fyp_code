# %%
from SEIRNetwork import SEIRNetwork
from Simulation import Simulation
from Simulator import Simulator
from matplotlib.pyplot import figure
from collections import Counter
import networkx as nx
from collections import defaultdict
from statistics import median

# %%
positiveCaseList_01 = []
for i in range(5):
    SEIR_network = SEIRNetwork()
    simulator = Simulator(SEIR_network)
    simulator.generate_simulation(T = 120)
    simulator.set_imported_case(time=1, average_introductions_per_day=1.0)
    simulator.set_social_distancing(time=1,global_rate=0.5)
    simulator.run()
    positiveCaseList_01.append(simulator.simulation.numPosTseries)
    print(f"Trial({i}) is done!")

avgPosCase_01 = defaultdict(list)
for iteration in positiveCaseList_01:
    for time_float,posCase in iteration.items():
        time = int(time_float)
        avgPosCase_01[time].append(posCase)
for key in avgPosCase_01:
    avgPosCase_01[key] = median(avgPosCase_01[key])

positiveCaseList = []
for i in range(5):
    SEIR_network = SEIRNetwork()
    simulator = Simulator(SEIR_network)
    simulator.generate_simulation(T = 120)
    simulator.set_imported_case(time=1, average_introductions_per_day=1.0)
    simulator.set_social_distancing(time=1,global_rate=1.0)
    simulator.run()
    positiveCaseList.append(simulator.simulation.numPosTseries)
    print(f"Trial({i}) is done!")


avgPosCase = defaultdict(list)
for iteration in positiveCaseList:
    for time_float,posCase in iteration.items():
        time = int(time_float)
        avgPosCase[time].append(posCase)
for key in avgPosCase:
    avgPosCase[key] = median(avgPosCase[key])
# Out:
# Generated overall age distribution:
# 0-4: 0.0706	(0.0258 from target)
# 10-14: 0.0816	(0.0314 from target)
# 15-19: 0.0736	(0.0222 from target)
# 20-24: 0.0515	(-0.0081 from target)
# 25-29: 0.0578	(-0.0119 from target)
# 30-34: 0.0640	(-0.0115 from target)
# 35-39: 0.0624	(-0.0101 from target)
# 40-44: 0.0651	(-0.0083 from target)
# 45-49: 0.0675	(-0.0078 from target)
# 5-9: 0.0760	(0.0261 from target)
# 50-54: 0.0612	(-0.0105 from target)
# 55-59: 0.0618	(-0.0130 from target)
# 60-64: 0.0560	(-0.0149 from target)
# 65-69: 0.0565	(-0.0025 from target)
# 70-74: 0.0432	(-0.0023 from target)
# 75-79: 0.0214	(-0.0014 from target)
# 80-84: 0.0152	(-0.0027 from target)
# 85-89: 0.0086	(-0.0008 from target)
# 90: 0.0060	(0.0005 from target)
#
# Generated household size distribution:
# 1: 0.1567	(0.0003 from target)
# 2: 0.2294	(-0.0088 from target)
# 3: 0.2198	(0.0058 from target)
# 4: 0.2095	(0.0088 from target)
# 5: 0.1122	(-0.0035 from target)
# 6: 0.0724	(-0.0027 from target)
# Num households: 3217
# mean household size: 3.1065084501977704
#
# Generating graph for 0-9...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 10-19...
# GENERATING WITH FARZ GENERATOR
# /Users/donghan37/Documents/Final Year Project/demo/.venv/lib/python3.8/site-packages/networkx/linalg/graphmatrix.py:187: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return adjacency_matrix(G, nodelist, dtype, weight)
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 20-64...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 65+...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# /Users/donghan37/Documents/Final Year Project/demo/lib/models.py:673: RuntimeWarning: invalid value encountered in divide
#   self.delta_Q = numpy.log(self.degree_Q) / numpy.log(numpy.mean(self.degree_Q)) if self.parameters[
# [UPDATE @ t = 1 (p-> 0.5)]
# [INTERVENTIONS @ t = 1.35 (6 (0.06%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 2.38 (6 (0.06%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 4.09 (6 (0.06%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 5.89 (5 (0.05%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 7.86 (4 (0.04%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 9.92 (3 (0.03%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 10.05 (2 (0.02%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 12.07 (1 (0.01%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 13.09 (0 (0.00%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 14.00 (0 (0.00%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [NEW EXPOSURE @ t = 15.00 (1 exposed)]
# [INTERVENTIONS @ t = 15.00 (0 (0.00%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 31.27 (1 (0.01%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 33.39 (2 (0.02%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 34.51 (3 (0.03%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 35.95 (4 (0.04%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 37.33 (6 (0.06%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 38.28 (6 (0.06%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 39.35 (7 (0.07%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 40.32 (7 (0.07%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 41.00 (7 (0.07%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 45.12 (6 (0.06%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 46.13 (6 (0.06%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [NEW EXPOSURE @ t = 49.16 (1 exposed)]
# [INTERVENTIONS @ t = 49.16 (5 (0.05%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 51.69 (4 (0.04%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 52.42 (3 (0.03%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 54.33 (4 (0.04%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [NEW EXPOSURE @ t = 55.82 (1 exposed)]
# [INTERVENTIONS @ t = 55.82 (5 (0.05%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 56.15 (6 (0.06%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 57.31 (7 (0.07%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 58.28 (6 (0.06%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 59.72 (7 (0.07%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 60.01 (7 (0.07%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [NEW EXPOSURE @ t = 61.70 (1 exposed)]
# [INTERVENTIONS @ t = 61.70 (6 (0.06%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 62.40 (6 (0.06%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 63.15 (7 (0.07%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 64.53 (8 (0.08%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [NEW EXPOSURE @ t = 66.42 (1 exposed)]
# [INTERVENTIONS @ t = 66.42 (9 (0.09%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 67.14 (9 (0.09%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [NEW EXPOSURE @ t = 68.02 (1 exposed)]
# [INTERVENTIONS @ t = 68.02 (10 (0.10%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 70.07 (12 (0.12%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 71.41 (14 (0.14%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 72.50 (14 (0.14%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 73.12 (14 (0.14%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 74.23 (15 (0.15%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 75.02 (16 (0.16%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 76.23 (16 (0.16%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 77.39 (16 (0.16%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 78.30 (17 (0.17%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 79.29 (16 (0.16%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 80.79 (16 (0.16%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 81.86 (18 (0.18%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 82.02 (18 (0.18%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 83.06 (18 (0.18%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [NEW EXPOSURE @ t = 84.18 (1 exposed)]
# [INTERVENTIONS @ t = 84.18 (18 (0.18%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 85.08 (21 (0.21%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 86.14 (21 (0.21%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 87.02 (22 (0.22%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 88.14 (23 (0.23%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 89.00 (24 (0.24%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [NEW EXPOSURE @ t = 90.03 (1 exposed)]
# [INTERVENTIONS @ t = 90.03 (30 (0.30%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 91.02 (32 (0.32%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 92.35 (33 (0.33%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 93.03 (35 (0.35%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 94.33 (39 (0.39%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 95.06 (43 (0.43%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 96.05 (46 (0.46%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 97.06 (51 (0.51%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [NEW EXPOSURE @ t = 98.04 (1 exposed)]
# [INTERVENTIONS @ t = 98.04 (57 (0.57%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [NEW EXPOSURE @ t = 99.01 (1 exposed)]
# [INTERVENTIONS @ t = 99.01 (61 (0.61%) infected)]
# 	6	tested due to symptoms  [+ 6 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 6 positive (100.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 100.06 (67 (0.67%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	13 entered isolation
# [INTERVENTIONS @ t = 101.03 (65 (0.65%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [INTERVENTIONS @ t = 102.02 (67 (0.67%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [INTERVENTIONS @ t = 103.05 (68 (0.68%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 104.07 (71 (0.71%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [NEW EXPOSURE @ t = 105.01 (1 exposed)]
# [INTERVENTIONS @ t = 105.01 (73 (0.73%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 106.05 (76 (0.76%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 107.00 (81 (0.81%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 108.02 (88 (0.88%) infected)]
# 	7	tested due to symptoms  [+ 5 positive (71.43 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	7	tested TOTAL            [+ 5 positive (71.43 %) +]
# 	10 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 109.02 (98 (0.98%) infected)]
# 	8	tested due to symptoms  [+ 7 positive (87.50 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	8	tested TOTAL            [+ 7 positive (87.50 %) +]
# 	10 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [INTERVENTIONS @ t = 110.00 (106 (1.06%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	15 entered isolation
# [INTERVENTIONS @ t = 111.01 (105 (1.05%) infected)]
# 	7	tested due to symptoms  [+ 7 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	7	tested TOTAL            [+ 7 positive (100.00 %) +]
# 	10 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	14 entered isolation
# [INTERVENTIONS @ t = 112.00 (113 (1.13%) infected)]
# 	6	tested due to symptoms  [+ 5 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 5 positive (83.33 %) +]
# 	10 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	13 entered isolation
# [INTERVENTIONS @ t = 113.04 (116 (1.16%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	17 entered isolation
# [INTERVENTIONS @ t = 114.02 (124 (1.24%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 115.02 (132 (1.32%) infected)]
# 	7	tested due to symptoms  [+ 7 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	7	tested TOTAL            [+ 7 positive (100.00 %) +]
# 	12 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 116.01 (133 (1.33%) infected)]
# 	8	tested due to symptoms  [+ 6 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	8	tested TOTAL            [+ 6 positive (75.00 %) +]
# 	15 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	17 entered isolation
# [INTERVENTIONS @ t = 117.03 (144 (1.44%) infected)]
# 	15	tested due to symptoms  [+ 14 positive (93.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 14 positive (93.33 %) +]
# 	22 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	14 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	22 entered isolation
# [INTERVENTIONS @ t = 118.01 (149 (1.49%) infected)]
# 	6	tested due to symptoms  [+ 5 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 5 positive (83.33 %) +]
# 	18 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	28 entered isolation
# [NEW EXPOSURE @ t = 119.02 (1 exposed)]
# [INTERVENTIONS @ t = 119.02 (160 (1.60%) infected)]
# 	12	tested due to symptoms  [+ 10 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 10 positive (83.33 %) +]
# 	16 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	10 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	32 entered isolation
# [INTERVENTIONS @ t = 120.04 (176 (1.76%) infected)]
# 	11	tested due to symptoms  [+ 9 positive (81.82 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	11	tested TOTAL            [+ 9 positive (81.82 %) +]
# 	20 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	21 entered isolation
# Trial(0) is done!
# Generated overall age distribution:
# 0-4: 0.0702	(0.0254 from target)
# 10-14: 0.0748	(0.0246 from target)
# 15-19: 0.0786	(0.0272 from target)
# 20-24: 0.0499	(-0.0097 from target)
# 25-29: 0.0548	(-0.0149 from target)
# 30-34: 0.0630	(-0.0125 from target)
# 35-39: 0.0652	(-0.0073 from target)
# 40-44: 0.0612	(-0.0122 from target)
# 45-49: 0.0649	(-0.0104 from target)
# 5-9: 0.0712	(0.0213 from target)
# 50-54: 0.0597	(-0.0120 from target)
# 55-59: 0.0654	(-0.0094 from target)
# 60-64: 0.0614	(-0.0095 from target)
# 65-69: 0.0605	(0.0015 from target)
# 70-74: 0.0449	(-0.0006 from target)
# 75-79: 0.0240	(0.0012 from target)
# 80-84: 0.0171	(-0.0008 from target)
# ...
# 	55 entered isolation
# [INTERVENTIONS @ t = 90.01 (326 (3.26%) infected)]
# 	13	tested due to symptoms  [+ 7 positive (53.85 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	13	tested TOTAL            [+ 7 positive (53.85 %) +]
# 	30 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	81 entered isolation
# [INTERVENTIONS @ t = 91.03 (338 (3.38%) infected)]
# 	15	tested due to symptoms  [+ 12 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 12 positive (80.00 %) +]
# 	32 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	65 entered isolation
# [INTERVENTIONS @ t = 92.00 (355 (3.55%) infected)]
# 	16	tested due to symptoms  [+ 13 positive (81.25 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	16	tested TOTAL            [+ 13 positive (81.25 %) +]
# 	33 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [NEW EXPOSURE @ t = 93.05 (1 exposed)]
# [INTERVENTIONS @ t = 93.05 (368 (3.68%) infected)]
# 	12	tested due to symptoms  [+ 8 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 8 positive (66.67 %) +]
# 	24 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	8 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	45 entered isolation
# [INTERVENTIONS @ t = 94.01 (385 (3.85%) infected)]
# 	22	tested due to symptoms  [+ 18 positive (81.82 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	22	tested TOTAL            [+ 18 positive (81.82 %) +]
# 	29 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	37 entered isolation
# [INTERVENTIONS @ t = 95.00 (406 (4.06%) infected)]
# 	22	tested due to symptoms  [+ 17 positive (77.27 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	22	tested TOTAL            [+ 17 positive (77.27 %) +]
# 	33 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	37 entered isolation
# [INTERVENTIONS @ t = 96.03 (426 (4.26%) infected)]
# 	26	tested due to symptoms  [+ 21 positive (80.77 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	26	tested TOTAL            [+ 21 positive (80.77 %) +]
# 	42 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	21 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	51 entered isolation
# [INTERVENTIONS @ t = 97.00 (433 (4.33%) infected)]
# 	26	tested due to symptoms  [+ 20 positive (76.92 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	26	tested TOTAL            [+ 20 positive (76.92 %) +]
# 	46 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	20 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	59 entered isolation
# [INTERVENTIONS @ t = 98.00 (452 (4.52%) infected)]
# 	20	tested due to symptoms  [+ 18 positive (90.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	20	tested TOTAL            [+ 18 positive (90.00 %) +]
# 	38 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	67 entered isolation
# [INTERVENTIONS @ t = 99.00 (476 (4.76%) infected)]
# 	21	tested due to symptoms  [+ 16 positive (76.19 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	21	tested TOTAL            [+ 16 positive (76.19 %) +]
# 	36 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	58 entered isolation
# [NEW EXPOSURE @ t = 100.01 (2 exposed)]
# [INTERVENTIONS @ t = 100.01 (500 (5.00%) infected)]
# 	19	tested due to symptoms  [+ 17 positive (89.47 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 17 positive (89.47 %) +]
# 	36 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	54 entered isolation
# [INTERVENTIONS @ t = 101.00 (521 (5.21%) infected)]
# 	25	tested due to symptoms  [+ 20 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	25	tested TOTAL            [+ 20 positive (80.00 %) +]
# 	36 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	20 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	52 entered isolation
# [NEW EXPOSURE @ t = 102.00 (1 exposed)]
# [INTERVENTIONS @ t = 102.00 (559 (5.59%) infected)]
# 	18	tested due to symptoms  [+ 17 positive (94.44 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	18	tested TOTAL            [+ 17 positive (94.44 %) +]
# 	33 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	53 entered isolation
# [INTERVENTIONS @ t = 103.01 (573 (5.73%) infected)]
# 	18	tested due to symptoms  [+ 15 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	18	tested TOTAL            [+ 15 positive (83.33 %) +]
# 	32 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	53 entered isolation
# [INTERVENTIONS @ t = 104.02 (296 (2.96%) infected)]
# 	17	tested due to symptoms  [+ 13 positive (76.47 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 13 positive (76.47 %) +]
# 	23 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	49 entered isolation
# [INTERVENTIONS @ t = 105.02 (317 (3.17%) infected)]
# 	19	tested due to symptoms  [+ 16 positive (84.21 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 16 positive (84.21 %) +]
# 	32 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	38 entered isolation
# [NEW EXPOSURE @ t = 106.01 (1 exposed)]
# [INTERVENTIONS @ t = 106.01 (328 (3.28%) infected)]
# 	11	tested due to symptoms  [+ 11 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	11	tested TOTAL            [+ 11 positive (100.00 %) +]
# 	25 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	45 entered isolation
# [INTERVENTIONS @ t = 107.01 (339 (3.39%) infected)]
# 	23	tested due to symptoms  [+ 19 positive (82.61 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	23	tested TOTAL            [+ 19 positive (82.61 %) +]
# 	32 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	41 entered isolation
# [INTERVENTIONS @ t = 108.01 (364 (3.64%) infected)]
# 	15	tested due to symptoms  [+ 10 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 10 positive (66.67 %) +]
# 	36 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	10 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	43 entered isolation
# [INTERVENTIONS @ t = 109.01 (397 (3.97%) infected)]
# 	12	tested due to symptoms  [+ 10 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 10 positive (83.33 %) +]
# 	21 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	10 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	55 entered isolation
# [INTERVENTIONS @ t = 110.04 (424 (4.24%) infected)]
# 	19	tested due to symptoms  [+ 14 positive (73.68 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 14 positive (73.68 %) +]
# 	26 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	14 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	31 entered isolation
# [INTERVENTIONS @ t = 111.00 (459 (4.59%) infected)]
# 	18	tested due to symptoms  [+ 16 positive (88.89 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	18	tested TOTAL            [+ 16 positive (88.89 %) +]
# 	36 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	36 entered isolation
# [INTERVENTIONS @ t = 112.02 (473 (4.73%) infected)]
# 	30	tested due to symptoms  [+ 25 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	30	tested TOTAL            [+ 25 positive (83.33 %) +]
# 	43 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	25 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	50 entered isolation
# [INTERVENTIONS @ t = 113.01 (507 (5.07%) infected)]
# 	27	tested due to symptoms  [+ 26 positive (96.30 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	27	tested TOTAL            [+ 26 positive (96.30 %) +]
# 	51 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	26 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	59 entered isolation
# [NEW EXPOSURE @ t = 114.00 (1 exposed)]
# [INTERVENTIONS @ t = 114.00 (524 (5.24%) infected)]
# 	26	tested due to symptoms  [+ 19 positive (73.08 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	26	tested TOTAL            [+ 19 positive (73.08 %) +]
# 	51 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	76 entered isolation
# [INTERVENTIONS @ t = 115.00 (563 (5.63%) infected)]
# 	26	tested due to symptoms  [+ 17 positive (65.38 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	26	tested TOTAL            [+ 17 positive (65.38 %) +]
# 	45 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	77 entered isolation
# [INTERVENTIONS @ t = 116.01 (584 (5.84%) infected)]
# 	22	tested due to symptoms  [+ 18 positive (81.82 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	22	tested TOTAL            [+ 18 positive (81.82 %) +]
# 	41 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	64 entered isolation
# [NEW EXPOSURE @ t = 117.01 (1 exposed)]
# [INTERVENTIONS @ t = 117.01 (330 (3.30%) infected)]
# 	12	tested due to symptoms  [+ 9 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 9 positive (75.00 %) +]
# 	23 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	58 entered isolation
# [INTERVENTIONS @ t = 118.03 (342 (3.42%) infected)]
# 	10	tested due to symptoms  [+ 8 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 8 positive (80.00 %) +]
# 	17 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	8 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	41 entered isolation
# [INTERVENTIONS @ t = 119.02 (353 (3.53%) infected)]
# 	24	tested due to symptoms  [+ 20 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	24	tested TOTAL            [+ 20 positive (83.33 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	20 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	26 entered isolation
# [INTERVENTIONS @ t = 120.02 (382 (3.82%) infected)]
# 	19	tested due to symptoms  [+ 16 positive (84.21 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 16 positive (84.21 %) +]
# 	39 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	36 entered isolation
# Trial(4) is done!

# %%
positiveCaseList_001 = []
for i in range(5):
    SEIR_network = SEIRNetwork()
    simulator = Simulator(SEIR_network)
    simulator.generate_simulation(T = 120)
    simulator.set_imported_case(time=1, average_introductions_per_day=1.0)
    simulator.set_social_distancing(time=1,global_rate=0.01)
    simulator.run()
    positiveCaseList_001.append(simulator.simulation.numPosTseries)
    print(f"Trial({i}) is done!")

avgPosCase_001 = defaultdict(list)
for iteration in positiveCaseList_001:
    for time_float,posCase in iteration.items():
        time = int(time_float)
        avgPosCase_001[time].append(posCase)
for key in avgPosCase_001:
    avgPosCase_001[key] = median(avgPosCase_001[key])
# Out:
# Generated overall age distribution:
# 0-4: 0.0649	(0.0201 from target)
# 10-14: 0.0832	(0.0330 from target)
# 15-19: 0.0778	(0.0264 from target)
# 20-24: 0.0513	(-0.0083 from target)
# 25-29: 0.0599	(-0.0098 from target)
# 30-34: 0.0633	(-0.0122 from target)
# 35-39: 0.0623	(-0.0102 from target)
# 40-44: 0.0566	(-0.0168 from target)
# 45-49: 0.0631	(-0.0122 from target)
# 5-9: 0.0768	(0.0269 from target)
# 50-54: 0.0585	(-0.0132 from target)
# 55-59: 0.0637	(-0.0111 from target)
# 60-64: 0.0604	(-0.0105 from target)
# 65-69: 0.0599	(0.0009 from target)
# 70-74: 0.0435	(-0.0020 from target)
# 75-79: 0.0232	(0.0004 from target)
# 80-84: 0.0178	(-0.0001 from target)
# 85-89: 0.0088	(-0.0006 from target)
# 90: 0.0050	(-0.0005 from target)
#
# Generated household size distribution:
# 1: 0.1474	(-0.0089 from target)
# 2: 0.2482	(0.0100 from target)
# 3: 0.2285	(0.0145 from target)
# 4: 0.2039	(0.0032 from target)
# 5: 0.1057	(-0.0101 from target)
# 6: 0.0663	(-0.0087 from target)
# Num households: 3256
# mean household size: 3.1065084501977704
#
# Generating graph for 0-9...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 10-19...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 20-64...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 65+...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# [INTERVENTIONS @ t = 0.37 (6 (0.06%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [UPDATE @ t = 1 (p-> 0.01)]
# [INTERVENTIONS @ t = 1.09 (9 (0.09%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [NEW EXPOSURE @ t = 2.22 (1 exposed)]
# [INTERVENTIONS @ t = 2.22 (9 (0.09%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [NEW EXPOSURE @ t = 3.72 (1 exposed)]
# [INTERVENTIONS @ t = 3.72 (10 (0.10%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 4.86 (11 (0.11%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 5.32 (11 (0.11%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 6.30 (10 (0.10%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 7.46 (11 (0.11%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 9.46 (11 (0.11%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 10.09 (11 (0.11%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 11.18 (11 (0.11%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 12.38 (12 (0.12%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 13.03 (12 (0.12%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 14.14 (12 (0.12%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 15.22 (12 (0.12%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 16.29 (9 (0.09%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 17.58 (10 (0.10%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 18.18 (11 (0.11%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 19.10 (12 (0.12%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 20.21 (15 (0.15%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [NEW EXPOSURE @ t = 21.42 (1 exposed)]
# [INTERVENTIONS @ t = 21.42 (18 (0.18%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 22.16 (20 (0.20%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 23.33 (19 (0.19%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 25.25 (21 (0.21%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 26.01 (21 (0.21%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 27.11 (22 (0.22%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 28.07 (22 (0.22%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 29.02 (22 (0.22%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [NEW EXPOSURE @ t = 30.10 (1 exposed)]
# [INTERVENTIONS @ t = 30.10 (23 (0.23%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 31.08 (25 (0.25%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 32.01 (27 (0.27%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 33.09 (27 (0.27%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 34.07 (31 (0.31%) infected)]
# 	2	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 35.08 (31 (0.31%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 36.03 (33 (0.33%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 37.00 (35 (0.35%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [INTERVENTIONS @ t = 38.02 (35 (0.35%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 39.08 (39 (0.39%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 40.12 (41 (0.41%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 41.03 (41 (0.41%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 42.06 (41 (0.41%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [NEW EXPOSURE @ t = 43.12 (1 exposed)]
# [INTERVENTIONS @ t = 43.12 (44 (0.44%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 44.06 (43 (0.43%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 45.04 (48 (0.48%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 46.01 (52 (0.52%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 47.08 (52 (0.52%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [INTERVENTIONS @ t = 48.03 (54 (0.54%) infected)]
# 	4	tested due to symptoms  [+ 2 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 2 positive (50.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 49.05 (58 (0.58%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 50.01 (56 (0.56%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [NEW EXPOSURE @ t = 51.08 (1 exposed)]
# [INTERVENTIONS @ t = 51.08 (63 (0.63%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 52.05 (69 (0.69%) infected)]
# 	6	tested due to symptoms  [+ 4 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 4 positive (66.67 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 53.04 (70 (0.70%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [INTERVENTIONS @ t = 54.14 (71 (0.71%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 55.03 (77 (0.77%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 56.04 (84 (0.84%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 57.05 (91 (0.91%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [NEW EXPOSURE @ t = 58.03 (1 exposed)]
# [INTERVENTIONS @ t = 58.03 (91 (0.91%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	13 entered isolation
# [INTERVENTIONS @ t = 59.01 (105 (1.05%) infected)]
# 	6	tested due to symptoms  [+ 3 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 3 positive (50.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [INTERVENTIONS @ t = 60.08 (113 (1.13%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 61.02 (116 (1.16%) infected)]
# 	6	tested due to symptoms  [+ 6 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 6 positive (100.00 %) +]
# 	10 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [INTERVENTIONS @ t = 62.02 (123 (1.23%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	13 entered isolation
# [NEW EXPOSURE @ t = 63.01 (1 exposed)]
# [INTERVENTIONS @ t = 63.01 (131 (1.31%) infected)]
# 	7	tested due to symptoms  [+ 5 positive (71.43 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	7	tested TOTAL            [+ 5 positive (71.43 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	15 entered isolation
# [INTERVENTIONS @ t = 64.01 (137 (1.37%) infected)]
# 	8	tested due to symptoms  [+ 8 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	8	tested TOTAL            [+ 8 positive (100.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	8 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 65.00 (145 (1.45%) infected)]
# 	10	tested due to symptoms  [+ 9 positive (90.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 9 positive (90.00 %) +]
# 	15 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	14 entered isolation
# [NEW EXPOSURE @ t = 66.01 (1 exposed)]
# [INTERVENTIONS @ t = 66.01 (155 (1.55%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	14 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	23 entered isolation
# [INTERVENTIONS @ t = 67.00 (166 (1.66%) infected)]
# 	6	tested due to symptoms  [+ 5 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 5 positive (83.33 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	23 entered isolation
# [INTERVENTIONS @ t = 68.02 (177 (1.77%) infected)]
# 	6	tested due to symptoms  [+ 6 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 6 positive (100.00 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	15 entered isolation
# [INTERVENTIONS @ t = 69.01 (192 (1.92%) infected)]
# 	9	tested due to symptoms  [+ 6 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	9	tested TOTAL            [+ 6 positive (66.67 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	16 entered isolation
# [INTERVENTIONS @ t = 70.00 (206 (2.06%) infected)]
# 	14	tested due to symptoms  [+ 12 positive (85.71 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	14	tested TOTAL            [+ 12 positive (85.71 %) +]
# 	21 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	17 entered isolation
# [INTERVENTIONS @ t = 71.02 (212 (2.12%) infected)]
# 	11	tested due to symptoms  [+ 7 positive (63.64 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	11	tested TOTAL            [+ 7 positive (63.64 %) +]
# 	27 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	27 entered isolation
# [INTERVENTIONS @ t = 72.00 (228 (2.28%) infected)]
# 	8	tested due to symptoms  [+ 6 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	8	tested TOTAL            [+ 6 positive (75.00 %) +]
# 	20 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [INTERVENTIONS @ t = 73.10 (241 (2.41%) infected)]
# 	13	tested due to symptoms  [+ 10 positive (76.92 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	13	tested TOTAL            [+ 10 positive (76.92 %) +]
# 	18 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	10 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	27 entered isolation
# [NEW EXPOSURE @ t = 74.00 (1 exposed)]
# [INTERVENTIONS @ t = 74.00 (247 (2.47%) infected)]
# 	8	tested due to symptoms  [+ 7 positive (87.50 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	8	tested TOTAL            [+ 7 positive (87.50 %) +]
# 	18 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	24 entered isolation
# [INTERVENTIONS @ t = 75.00 (268 (2.68%) infected)]
# 	19	tested due to symptoms  [+ 13 positive (68.42 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 13 positive (68.42 %) +]
# 	22 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	28 entered isolation
# [INTERVENTIONS @ t = 76.01 (284 (2.84%) infected)]
# 	20	tested due to symptoms  [+ 19 positive (95.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	20	tested TOTAL            [+ 19 positive (95.00 %) +]
# 	33 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	29 entered isolation
# [INTERVENTIONS @ t = 77.02 (292 (2.92%) infected)]
# 	16	tested due to symptoms  [+ 14 positive (87.50 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	16	tested TOTAL            [+ 14 positive (87.50 %) +]
# 	29 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	14 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	46 entered isolation
# [INTERVENTIONS @ t = 78.00 (292 (2.92%) infected)]
# 	15	tested due to symptoms  [+ 11 positive (73.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 11 positive (73.33 %) +]
# 	20 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	48 entered isolation
# [INTERVENTIONS @ t = 79.01 (304 (3.04%) infected)]
# 	12	tested due to symptoms  [+ 10 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 10 positive (83.33 %) +]
# 	23 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	10 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	34 entered isolation
# [INTERVENTIONS @ t = 80.00 (312 (3.12%) infected)]
# 	22	tested due to symptoms  [+ 17 positive (77.27 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	22	tested TOTAL            [+ 17 positive (77.27 %) +]
# 	31 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	34 entered isolation
# [INTERVENTIONS @ t = 81.01 (322 (3.22%) infected)]
# 	17	tested due to symptoms  [+ 12 positive (70.59 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 12 positive (70.59 %) +]
# 	33 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	41 entered isolation
# [INTERVENTIONS @ t = 82.00 (329 (3.29%) infected)]
# 	17	tested due to symptoms  [+ 13 positive (76.47 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 13 positive (76.47 %) +]
# 	29 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	50 entered isolation
# [INTERVENTIONS @ t = 83.01 (340 (3.40%) infected)]
# 	18	tested due to symptoms  [+ 16 positive (88.89 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	18	tested TOTAL            [+ 16 positive (88.89 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	41 entered isolation
# [INTERVENTIONS @ t = 84.03 (352 (3.52%) infected)]
# 	10	tested due to symptoms  [+ 5 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 5 positive (50.00 %) +]
# 	23 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	41 entered isolation
# [INTERVENTIONS @ t = 85.01 (365 (3.65%) infected)]
# 	17	tested due to symptoms  [+ 15 positive (88.24 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 15 positive (88.24 %) +]
# 	22 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [INTERVENTIONS @ t = 86.00 (377 (3.77%) infected)]
# 	24	tested due to symptoms  [+ 18 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	24	tested TOTAL            [+ 18 positive (75.00 %) +]
# 	36 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	27 entered isolation
# [INTERVENTIONS @ t = 87.01 (385 (3.85%) infected)]
# 	20	tested due to symptoms  [+ 17 positive (85.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	20	tested TOTAL            [+ 17 positive (85.00 %) +]
# 	47 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	51 entered isolation
# [INTERVENTIONS @ t = 88.00 (390 (3.90%) infected)]
# 	12	tested due to symptoms  [+ 10 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 10 positive (83.33 %) +]
# 	36 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	10 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	65 entered isolation
# [INTERVENTIONS @ t = 89.00 (401 (4.01%) infected)]
# 	23	tested due to symptoms  [+ 18 positive (78.26 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	23	tested TOTAL            [+ 18 positive (78.26 %) +]
# 	36 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	53 entered isolation
# [NEW EXPOSURE @ t = 90.00 (1 exposed)]
# [INTERVENTIONS @ t = 90.00 (421 (4.21%) infected)]
# 	21	tested due to symptoms  [+ 19 positive (90.48 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	21	tested TOTAL            [+ 19 positive (90.48 %) +]
# 	39 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	19 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	46 entered isolation
# [INTERVENTIONS @ t = 91.01 (433 (4.33%) infected)]
# 	17	tested due to symptoms  [+ 17 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 17 positive (100.00 %) +]
# 	31 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	57 entered isolation
# [INTERVENTIONS @ t = 92.00 (452 (4.52%) infected)]
# 	26	tested due to symptoms  [+ 20 positive (76.92 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	26	tested TOTAL            [+ 20 positive (76.92 %) +]
# 	42 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	20 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	50 entered isolation
# [INTERVENTIONS @ t = 93.00 (481 (4.81%) infected)]
# 	33	tested due to symptoms  [+ 24 positive (72.73 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	33	tested TOTAL            [+ 24 positive (72.73 %) +]
# 	58 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	24 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	59 entered isolation
# [INTERVENTIONS @ t = 94.01 (486 (4.86%) infected)]
# ...
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 90.18 (28 (0.28%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 91.11 (29 (0.29%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 92.19 (28 (0.28%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [NEW EXPOSURE @ t = 93.18 (1 exposed)]
# [INTERVENTIONS @ t = 93.18 (28 (0.28%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 94.12 (32 (0.32%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 95.09 (34 (0.34%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	13 entered isolation
# [INTERVENTIONS @ t = 96.16 (34 (0.34%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 97.17 (37 (0.37%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 98.09 (39 (0.39%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 99.07 (36 (0.36%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 100.19 (39 (0.39%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 101.20 (40 (0.40%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 102.00 (44 (0.44%) infected)]
# 	7	tested due to symptoms  [+ 3 positive (42.86 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	7	tested TOTAL            [+ 3 positive (42.86 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 103.18 (42 (0.42%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 104.20 (40 (0.40%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 105.02 (40 (0.40%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 106.27 (46 (0.46%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 107.11 (45 (0.45%) infected)]
# 	4	tested due to symptoms  [+ 4 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 4 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 108.16 (46 (0.46%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 109.28 (54 (0.54%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [INTERVENTIONS @ t = 110.02 (56 (0.56%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 111.01 (61 (0.61%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 112.09 (64 (0.64%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 113.13 (67 (0.67%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 114.00 (75 (0.75%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [NEW EXPOSURE @ t = 115.02 (1 exposed)]
# [INTERVENTIONS @ t = 115.02 (82 (0.82%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 116.02 (92 (0.92%) infected)]
# 	6	tested due to symptoms  [+ 3 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 3 positive (50.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 117.04 (92 (0.92%) infected)]
# 	3	tested due to symptoms  [+ 1 positive (33.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 1 positive (33.33 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 118.02 (95 (0.95%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [NEW EXPOSURE @ t = 119.11 (1 exposed)]
# [INTERVENTIONS @ t = 119.11 (103 (1.03%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 120.02 (115 (1.15%) infected)]
# 	7	tested due to symptoms  [+ 4 positive (57.14 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	7	tested TOTAL            [+ 4 positive (57.14 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# Trial(4) is done!

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(15,5))

plt.bar(avgPosCase.keys(),avgPosCase.values(),label='Global Infection Rate: 1.0')
plt.bar(avgPosCase_01.keys(),avgPosCase_01.values(),color = 'orange',label='Global Infection Rate: 0.5')
plt.bar(avgPosCase_001.keys(),avgPosCase_001.values(),color='red',label='Global Infection Rate: 0.01',alpha=0.5)

plt.xlabel("Days")
plt.ylabel("Number of Persons")
plt.legend()
plt.title("Number of Positive Cases with Different Global Infection Rate")
# Out:
# Text(0.5, 1.0, 'Number of Positive Cases with Different Global Infection Rate')
