# %%
from SEIRNetwork import SEIRNetwork
from Simulation import Simulation
from Simulator import Simulator
from matplotlib.pyplot import figure
from collections import Counter
import networkx as nx
from collections import defaultdict
from statistics import median

# %%
positiveCaseList_01 = []
for i in range(5):
    SEIR_network = SEIRNetwork()
    simulator = Simulator(SEIR_network)
    simulator.generate_simulation(T = 120)
    simulator.set_imported_case(time=1, average_introductions_per_day=1.0)
    simulator.set_social_distancing(time=1,global_rate=0.5)
    simulator.set_trace_together(time=0, tracing_lag=1,tracing_compliance_rate=0.0)

    simulator.run()
    positiveCaseList_01.append(simulator.simulation.numPosTseries)
    print(f"Trial({i}) is done!")

avgPosCase_01 = defaultdict(list)
for iteration in positiveCaseList_01:
    for time_float,posCase in iteration.items():
        time = int(time_float)
        avgPosCase_01[time].append(posCase)
for key in avgPosCase_01:
    avgPosCase_01[key] = median(avgPosCase_01[key])

positiveCaseList = []
for i in range(5):
    SEIR_network = SEIRNetwork()
    simulator = Simulator(SEIR_network)
    simulator.generate_simulation(T = 120)
    simulator.set_imported_case(time=1, average_introductions_per_day=1.0)
    simulator.set_trace_together(time=0, tracing_lag=1,tracing_compliance_rate=0.0)
    simulator.set_social_distancing(time=1,global_rate=0.001)
    simulator.simulation.set_seir_network_params(
        time=1,
        G=simulator.SEIRModel.get_network("household")
        )
    simulator.run()
    positiveCaseList.append(simulator.simulation.numPosTseries)
    print(f"Trial({i}) is done!")


avgPosCase = defaultdict(list)
for iteration in positiveCaseList:
    for time_float,posCase in iteration.items():
        time = int(time_float)
        avgPosCase[time].append(posCase)
for key in avgPosCase:
    avgPosCase[key] = median(avgPosCase[key])
# Out:
# Generated overall age distribution:
# 0-4: 0.0696	(0.0248 from target)
# 10-14: 0.0808	(0.0306 from target)
# 15-19: 0.0774	(0.0260 from target)
# 20-24: 0.0499	(-0.0097 from target)
# 25-29: 0.0571	(-0.0126 from target)
# 30-34: 0.0635	(-0.0120 from target)
# 35-39: 0.0621	(-0.0104 from target)
# 40-44: 0.0625	(-0.0109 from target)
# 45-49: 0.0643	(-0.0110 from target)
# 5-9: 0.0799	(0.0300 from target)
# 50-54: 0.0568	(-0.0149 from target)
# 55-59: 0.0642	(-0.0106 from target)
# 60-64: 0.0660	(-0.0049 from target)
# 65-69: 0.0523	(-0.0067 from target)
# 70-74: 0.0437	(-0.0018 from target)
# 75-79: 0.0209	(-0.0019 from target)
# 80-84: 0.0146	(-0.0033 from target)
# 85-89: 0.0097	(0.0003 from target)
# 90: 0.0047	(-0.0008 from target)
#
# Generated household size distribution:
# 1: 0.1622	(0.0059 from target)
# 2: 0.2433	(0.0051 from target)
# 3: 0.2175	(0.0036 from target)
# 4: 0.1868	(-0.0139 from target)
# 5: 0.1174	(0.0016 from target)
# 6: 0.0728	(-0.0023 from target)
# Num households: 3255
# mean household size: 3.1065084501977704
#
# Generating graph for 0-9...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 10-19...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 20-64...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 65+...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# [UPDATE @ t = 0 (tracing_compliance-> [False False False ... False False False])]
# [UPDATE @ t = 0 (tracing_lag-> 1)]
# [INTERVENTIONS @ t = 0.68 (7 (0.07%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [UPDATE @ t = 1 (p-> 0.5)]
# [NEW EXPOSURE @ t = 1.24 (1 exposed)]
# [INTERVENTIONS @ t = 1.24 (8 (0.08%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 3.08 (8 (0.08%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [NEW EXPOSURE @ t = 4.74 (1 exposed)]
# [INTERVENTIONS @ t = 4.74 (9 (0.09%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 5.19 (11 (0.11%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 6.05 (9 (0.09%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 7.21 (11 (0.11%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [NEW EXPOSURE @ t = 8.10 (1 exposed)]
# [INTERVENTIONS @ t = 8.10 (11 (0.11%) infected)]
# 	2	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 9.18 (14 (0.14%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 10.00 (13 (0.13%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [NEW EXPOSURE @ t = 11.30 (1 exposed)]
# [INTERVENTIONS @ t = 11.30 (13 (0.13%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 12.51 (15 (0.15%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 13.22 (16 (0.16%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 14.22 (17 (0.17%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 15.75 (17 (0.17%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 16.14 (18 (0.18%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 18.00 (17 (0.17%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 18.76 (17 (0.17%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 19.48 (17 (0.17%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [NEW EXPOSURE @ t = 20.22 (1 exposed)]
# [INTERVENTIONS @ t = 20.22 (16 (0.16%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 21.12 (17 (0.17%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 22.66 (17 (0.17%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 23.17 (16 (0.16%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 24.88 (17 (0.17%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 25.78 (16 (0.16%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 26.14 (15 (0.15%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 27.04 (16 (0.16%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 28.82 (19 (0.19%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 29.09 (20 (0.20%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 30.08 (21 (0.21%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 31.32 (20 (0.20%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 32.52 (23 (0.23%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 33.16 (24 (0.24%) infected)]
# 	2	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 34.06 (27 (0.27%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 35.29 (26 (0.26%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 36.47 (25 (0.25%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 37.08 (24 (0.24%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 38.26 (26 (0.26%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [NEW EXPOSURE @ t = 39.15 (1 exposed)]
# [INTERVENTIONS @ t = 39.15 (24 (0.24%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 40.07 (24 (0.24%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 41.19 (24 (0.24%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 42.14 (25 (0.25%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 43.24 (30 (0.30%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 44.02 (34 (0.34%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 45.02 (36 (0.36%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 46.22 (36 (0.36%) infected)]
# 	4	tested due to symptoms  [+ 2 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 2 positive (50.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 47.07 (38 (0.38%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 48.00 (46 (0.46%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [INTERVENTIONS @ t = 49.01 (45 (0.45%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 50.13 (50 (0.50%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 51.06 (55 (0.55%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 52.02 (59 (0.59%) infected)]
# 	4	tested due to symptoms  [+ 4 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 4 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [NEW EXPOSURE @ t = 53.07 (1 exposed)]
# [INTERVENTIONS @ t = 53.07 (71 (0.71%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 54.03 (73 (0.73%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [INTERVENTIONS @ t = 55.01 (75 (0.75%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 56.12 (85 (0.85%) infected)]
# 	3	tested due to symptoms  [+ 3 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 3 positive (100.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 57.07 (84 (0.84%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [INTERVENTIONS @ t = 58.00 (89 (0.89%) infected)]
# 	6	tested due to symptoms  [+ 4 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 4 positive (66.67 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	9 entered isolation
# [INTERVENTIONS @ t = 59.01 (97 (0.97%) infected)]
# 	6	tested due to symptoms  [+ 6 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 6 positive (100.00 %) +]
# 	12 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 60.07 (107 (1.07%) infected)]
# 	4	tested due to symptoms  [+ 4 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 4 positive (100.00 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	16 entered isolation
# [INTERVENTIONS @ t = 61.06 (115 (1.15%) infected)]
# 	6	tested due to symptoms  [+ 3 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 3 positive (50.00 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	17 entered isolation
# [NEW EXPOSURE @ t = 62.05 (1 exposed)]
# [INTERVENTIONS @ t = 62.05 (119 (1.19%) infected)]
# 	8	tested due to symptoms  [+ 6 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	8	tested TOTAL            [+ 6 positive (75.00 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [INTERVENTIONS @ t = 63.03 (121 (1.21%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	12 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	14 entered isolation
# [INTERVENTIONS @ t = 64.03 (128 (1.28%) infected)]
# 	4	tested due to symptoms  [+ 2 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 2 positive (50.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	18 entered isolation
# [NEW EXPOSURE @ t = 65.05 (1 exposed)]
# [INTERVENTIONS @ t = 65.05 (139 (1.39%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	10 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	13 entered isolation
# [INTERVENTIONS @ t = 66.03 (145 (1.45%) infected)]
# 	9	tested due to symptoms  [+ 9 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	9	tested TOTAL            [+ 9 positive (100.00 %) +]
# 	16 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [INTERVENTIONS @ t = 67.02 (145 (1.45%) infected)]
# 	12	tested due to symptoms  [+ 12 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 12 positive (100.00 %) +]
# 	18 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	19 entered isolation
# [INTERVENTIONS @ t = 68.02 (154 (1.54%) infected)]
# 	12	tested due to symptoms  [+ 9 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 9 positive (75.00 %) +]
# 	18 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	27 entered isolation
# [INTERVENTIONS @ t = 69.00 (168 (1.68%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	13 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	30 entered isolation
# [INTERVENTIONS @ t = 70.02 (168 (1.68%) infected)]
# 	9	tested due to symptoms  [+ 6 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	9	tested TOTAL            [+ 6 positive (66.67 %) +]
# 	12 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	22 entered isolation
# [INTERVENTIONS @ t = 71.04 (172 (1.72%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	10 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	16 entered isolation
# [INTERVENTIONS @ t = 72.04 (176 (1.76%) infected)]
# 	10	tested due to symptoms  [+ 7 positive (70.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 7 positive (70.00 %) +]
# 	16 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	7 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	16 entered isolation
# [INTERVENTIONS @ t = 73.06 (181 (1.81%) infected)]
# 	10	tested due to symptoms  [+ 6 positive (60.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 6 positive (60.00 %) +]
# 	17 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	20 entered isolation
# [INTERVENTIONS @ t = 74.07 (188 (1.88%) infected)]
# 	10	tested due to symptoms  [+ 8 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 8 positive (80.00 %) +]
# 	14 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	8 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	24 entered isolation
# [INTERVENTIONS @ t = 75.01 (196 (1.96%) infected)]
# 	6	tested due to symptoms  [+ 5 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 5 positive (83.33 %) +]
# 	13 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	20 entered isolation
# [INTERVENTIONS @ t = 76.05 (205 (2.05%) infected)]
# 	14	tested due to symptoms  [+ 11 positive (78.57 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	14	tested TOTAL            [+ 11 positive (78.57 %) +]
# 	17 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	21 entered isolation
# [INTERVENTIONS @ t = 77.01 (212 (2.12%) infected)]
# 	5	tested due to symptoms  [+ 3 positive (60.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 3 positive (60.00 %) +]
# 	16 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	22 entered isolation
# [INTERVENTIONS @ t = 78.00 (221 (2.21%) infected)]
# 	12	tested due to symptoms  [+ 11 positive (91.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 11 positive (91.67 %) +]
# 	15 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	27 entered isolation
# [INTERVENTIONS @ t = 79.02 (236 (2.36%) infected)]
# 	10	tested due to symptoms  [+ 8 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 8 positive (80.00 %) +]
# 	17 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	8 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	18 entered isolation
# [INTERVENTIONS @ t = 80.06 (249 (2.49%) infected)]
# 	14	tested due to symptoms  [+ 11 positive (78.57 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	14	tested TOTAL            [+ 11 positive (78.57 %) +]
# 	17 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	28 entered isolation
# [INTERVENTIONS @ t = 81.01 (266 (2.66%) infected)]
# 	16	tested due to symptoms  [+ 14 positive (87.50 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	16	tested TOTAL            [+ 14 positive (87.50 %) +]
# 	20 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	14 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	25 entered isolation
# [INTERVENTIONS @ t = 82.00 (275 (2.75%) infected)]
# 	14	tested due to symptoms  [+ 8 positive (57.14 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	14	tested TOTAL            [+ 8 positive (57.14 %) +]
# 	25 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	8 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	31 entered isolation
# [INTERVENTIONS @ t = 83.01 (293 (2.93%) infected)]
# 	15	tested due to symptoms  [+ 12 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 12 positive (80.00 %) +]
# 	24 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [INTERVENTIONS @ t = 84.00 (314 (3.14%) infected)]
# 	16	tested due to symptoms  [+ 15 positive (93.75 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	16	tested TOTAL            [+ 15 positive (93.75 %) +]
# 	26 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	32 entered isolation
# [INTERVENTIONS @ t = 85.00 (324 (3.24%) infected)]
# 	17	tested due to symptoms  [+ 13 positive (76.47 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 13 positive (76.47 %) +]
# 	27 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	38 entered isolation
# [INTERVENTIONS @ t = 86.00 (334 (3.34%) infected)]
# 	16	tested due to symptoms  [+ 14 positive (87.50 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	16	tested TOTAL            [+ 14 positive (87.50 %) +]
# 	25 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	14 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	42 entered isolation
# [INTERVENTIONS @ t = 87.00 (357 (3.57%) infected)]
# 	17	tested due to symptoms  [+ 15 positive (88.24 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 15 positive (88.24 %) +]
# 	23 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	38 entered isolation
# [INTERVENTIONS @ t = 88.00 (372 (3.72%) infected)]
# 	19	tested due to symptoms  [+ 16 positive (84.21 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	19	tested TOTAL            [+ 16 positive (84.21 %) +]
# 	26 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	37 entered isolation
# [INTERVENTIONS @ t = 89.01 (388 (3.88%) infected)]
# 	21	tested due to symptoms  [+ 16 positive (76.19 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	21	tested TOTAL            [+ 16 positive (76.19 %) +]
# 	34 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	16 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	41 entered isolation
# [INTERVENTIONS @ t = 90.00 (407 (4.07%) infected)]
# 	20	tested due to symptoms  [+ 18 positive (90.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	20	tested TOTAL            [+ 18 positive (90.00 %) +]
# 	36 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	18 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	50 entered isolation
# [INTERVENTIONS @ t = 91.00 (429 (4.29%) infected)]
# 	17	tested due to symptoms  [+ 15 positive (88.24 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	17	tested TOTAL            [+ 15 positive (88.24 %) +]
# 	30 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	52 entered isolation
# [INTERVENTIONS @ t = 92.00 (458 (4.58%) infected)]
# 	28	tested due to symptoms  [+ 26 positive (92.86 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	28	tested TOTAL            [+ 26 positive (92.86 %) +]
# 	43 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	26 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	48 entered isolation
# ...
# [NEW EXPOSURE @ t = 42.20 (1 exposed)]
# [INTERVENTIONS @ t = 42.20 (2 (0.02%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 45.62 (2 (0.02%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 48.56 (2 (0.02%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 51.94 (3 (0.03%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 52.53 (3 (0.03%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 53.33 (3 (0.03%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 54.24 (4 (0.04%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 55.14 (3 (0.03%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 56.96 (3 (0.03%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 58.92 (2 (0.02%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 65.65 (2 (0.02%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 71.72 (1 (0.01%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 75.32 (0 (0.00%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 76.00 (0 (0.00%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 77.00 (0 (0.00%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [NEW EXPOSURE @ t = 78.00 (1 exposed)]
# [INTERVENTIONS @ t = 78.00 (0 (0.00%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 81.95 (1 (0.01%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 84.58 (1 (0.01%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 86.16 (2 (0.02%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 88.80 (3 (0.03%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 89.66 (2 (0.02%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [NEW EXPOSURE @ t = 96.55 (1 exposed)]
# [INTERVENTIONS @ t = 96.55 (3 (0.03%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 103.72 (4 (0.04%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 104.56 (4 (0.04%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 106.68 (4 (0.04%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 107.48 (3 (0.03%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 110.55 (2 (0.02%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 111.19 (1 (0.01%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 117.84 (0 (0.00%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 118.01 (0 (0.00%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 119.01 (0 (0.00%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 120.01 (0 (0.00%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# Trial(4) is done!

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(15,5))

plt.bar(avgPosCase_01.keys(),avgPosCase_01.values(),color = 'orange',label='No Circuit Breaker', alpha=0.5)
plt.bar(avgPosCase.keys(),avgPosCase.values(),label='Circuit Braker from Day 0')


plt.xlabel("Days")
plt.ylabel("Number of Persons")
plt.legend()
plt.title("Number of Positive Cases with and without Circuit Breaker")
# Out:
# Text(0.5, 1.0, 'Number of Positive Cases with and without Circuit Breaker')

# %%
positiveCaseList_01 = []
for i in range(5):
    SEIR_network = SEIRNetwork()
    simulator = Simulator(SEIR_network)
    simulator.generate_simulation(T = 160)
    simulator.set_imported_case(time=1, average_introductions_per_day=1.0)
    simulator.set_social_distancing(time=1,global_rate=0.5)
    simulator.set_trace_together(time=0, tracing_lag=1,tracing_compliance_rate=0.0)

    simulator.run()
    positiveCaseList_01.append(simulator.simulation.numPosTseries)
    print(f"Trial({i}) is done!")

avgPosCase_01 = defaultdict(list)
for iteration in positiveCaseList_01:
    for time_float,posCase in iteration.items():
        time = int(time_float)
        avgPosCase_01[time].append(posCase)
for key in avgPosCase_01:
    avgPosCase_01[key] = median(avgPosCase_01[key])

positiveCaseList = []
for i in range(5):
    SEIR_network = SEIRNetwork()
    simulator = Simulator(SEIR_network)
    simulator.generate_simulation(T = 160)
    simulator.set_imported_case(time=1, average_introductions_per_day=1.0)
    simulator.set_social_distancing(time=1,global_rate=0.5)
    simulator.set_trace_together(time=0, tracing_lag=1,tracing_compliance_rate=0.0)

    simulator.set_social_distancing(time=80,global_rate=0.001)
    simulator.simulation.set_seir_network_params(
        time=80,
        G=simulator.SEIRModel.get_network("household")
        )
    simulator.run()
    positiveCaseList.append(simulator.simulation.numPosTseries)
    print(f"Trial({i}) is done!")


avgPosCase = defaultdict(list)
for iteration in positiveCaseList:
    for time_float,posCase in iteration.items():
        time = int(time_float)
        avgPosCase[time].append(posCase)
for key in avgPosCase:
    avgPosCase[key] = median(avgPosCase[key])
# Out:
# Generated overall age distribution:
# 0-4: 0.0676	(0.0228 from target)
# 10-14: 0.0780	(0.0278 from target)
# 15-19: 0.0769	(0.0255 from target)
# 20-24: 0.0514	(-0.0082 from target)
# 25-29: 0.0540	(-0.0157 from target)
# 30-34: 0.0653	(-0.0102 from target)
# 35-39: 0.0621	(-0.0104 from target)
# 40-44: 0.0637	(-0.0097 from target)
# 45-49: 0.0610	(-0.0143 from target)
# 5-9: 0.0698	(0.0199 from target)
# 50-54: 0.0633	(-0.0084 from target)
# 55-59: 0.0657	(-0.0091 from target)
# 60-64: 0.0643	(-0.0066 from target)
# 65-69: 0.0584	(-0.0006 from target)
# 70-74: 0.0443	(-0.0012 from target)
# 75-79: 0.0215	(-0.0013 from target)
# 80-84: 0.0168	(-0.0011 from target)
# 85-89: 0.0106	(0.0012 from target)
# 90: 0.0053	(-0.0002 from target)
#
# Generated household size distribution:
# 1: 0.1596	(0.0032 from target)
# 2: 0.2351	(-0.0030 from target)
# 3: 0.2103	(-0.0037 from target)
# 4: 0.2044	(0.0036 from target)
# 5: 0.1117	(-0.0040 from target)
# 6: 0.0790	(0.0039 from target)
# Num households: 3215
# mean household size: 3.1065084501977704
#
# Generating graph for 0-9...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 10-19...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 20-64...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 65+...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# [UPDATE @ t = 0 (tracing_compliance-> [False False False ... False False False])]
# [UPDATE @ t = 0 (tracing_lag-> 1)]
# [INTERVENTIONS @ t = 0.01 (5 (0.05%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [UPDATE @ t = 1 (p-> 0.5)]
# [INTERVENTIONS @ t = 1.10 (7 (0.07%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 2.20 (5 (0.05%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 3.12 (7 (0.07%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 4.83 (7 (0.07%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 5.06 (7 (0.07%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 6.06 (7 (0.07%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 7.39 (8 (0.08%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 8.77 (6 (0.06%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 9.86 (6 (0.06%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 10.39 (7 (0.07%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 11.36 (8 (0.08%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 12.21 (8 (0.08%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 13.61 (8 (0.08%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 14.07 (8 (0.08%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 15.95 (8 (0.08%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 16.55 (9 (0.09%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 17.14 (8 (0.08%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 18.55 (8 (0.08%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 19.29 (9 (0.09%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 20.09 (9 (0.09%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 21.22 (9 (0.09%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 22.01 (10 (0.10%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 24.20 (11 (0.11%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 25.57 (10 (0.10%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 26.21 (12 (0.12%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 27.08 (11 (0.11%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 28.03 (13 (0.13%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [NEW EXPOSURE @ t = 29.17 (1 exposed)]
# [INTERVENTIONS @ t = 29.17 (10 (0.10%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 30.06 (13 (0.13%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 31.15 (14 (0.14%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 32.50 (15 (0.15%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 33.19 (15 (0.15%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 34.06 (16 (0.16%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 35.30 (17 (0.17%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 36.16 (19 (0.19%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 37.01 (18 (0.18%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 38.22 (20 (0.20%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 39.27 (20 (0.20%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 40.45 (20 (0.20%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 41.20 (22 (0.22%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 42.28 (20 (0.20%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 43.01 (22 (0.22%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 44.23 (23 (0.23%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 45.05 (24 (0.24%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 46.49 (28 (0.28%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 47.01 (32 (0.32%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 48.04 (34 (0.34%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 49.06 (34 (0.34%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 50.17 (39 (0.39%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 51.03 (45 (0.45%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 52.06 (47 (0.47%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 53.09 (45 (0.45%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 54.05 (54 (0.54%) infected)]
# 	5	tested due to symptoms  [+ 4 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 4 positive (80.00 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 55.02 (64 (0.64%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [INTERVENTIONS @ t = 56.03 (66 (0.66%) infected)]
# 	7	tested due to symptoms  [+ 6 positive (85.71 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	7	tested TOTAL            [+ 6 positive (85.71 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 57.03 (68 (0.68%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	12 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 58.01 (74 (0.74%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	18 entered isolation
# [NEW EXPOSURE @ t = 59.03 (1 exposed)]
# [INTERVENTIONS @ t = 59.03 (76 (0.76%) infected)]
# 	6	tested due to symptoms  [+ 6 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 6 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 60.01 (83 (0.83%) infected)]
# 	2	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	8 entered isolation
# [INTERVENTIONS @ t = 61.00 (93 (0.93%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	11 entered isolation
# [INTERVENTIONS @ t = 62.01 (95 (0.95%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 63.02 (103 (1.03%) infected)]
# 	6	tested due to symptoms  [+ 6 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 6 positive (100.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [NEW EXPOSURE @ t = 64.01 (1 exposed)]
# [INTERVENTIONS @ t = 64.01 (111 (1.11%) infected)]
# 	6	tested due to symptoms  [+ 4 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 4 positive (66.67 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [INTERVENTIONS @ t = 65.03 (114 (1.14%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	17 entered isolation
# [INTERVENTIONS @ t = 66.01 (119 (1.19%) infected)]
# 	4	tested due to symptoms  [+ 3 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 3 positive (75.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	13 entered isolation
# [INTERVENTIONS @ t = 67.09 (127 (1.27%) infected)]
# 	12	tested due to symptoms  [+ 10 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 10 positive (83.33 %) +]
# 	15 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	10 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [NEW EXPOSURE @ t = 68.16 (1 exposed)]
# [INTERVENTIONS @ t = 68.16 (128 (1.28%) infected)]
# 	4	tested due to symptoms  [+ 2 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	4	tested TOTAL            [+ 2 positive (50.00 %) +]
# 	15 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	18 entered isolation
# [NEW EXPOSURE @ t = 69.03 (1 exposed)]
# [INTERVENTIONS @ t = 69.03 (136 (1.36%) infected)]
# 	6	tested due to symptoms  [+ 6 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 6 positive (100.00 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	6 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	25 entered isolation
# [INTERVENTIONS @ t = 70.03 (149 (1.49%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	9 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	13 entered isolation
# [INTERVENTIONS @ t = 71.01 (157 (1.57%) infected)]
# 	10	tested due to symptoms  [+ 9 positive (90.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 9 positive (90.00 %) +]
# 	10 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	15 entered isolation
# [INTERVENTIONS @ t = 72.03 (167 (1.67%) infected)]
# 	6	tested due to symptoms  [+ 4 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	6	tested TOTAL            [+ 4 positive (66.67 %) +]
# 	11 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	4 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	15 entered isolation
# [INTERVENTIONS @ t = 73.08 (179 (1.79%) infected)]
# 	12	tested due to symptoms  [+ 8 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 8 positive (66.67 %) +]
# 	18 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	8 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	20 entered isolation
# [NEW EXPOSURE @ t = 74.00 (1 exposed)]
# [INTERVENTIONS @ t = 74.00 (185 (1.85%) infected)]
# 	10	tested due to symptoms  [+ 9 positive (90.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	10	tested TOTAL            [+ 9 positive (90.00 %) +]
# 	21 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	22 entered isolation
# [NEW EXPOSURE @ t = 75.02 (1 exposed)]
# [INTERVENTIONS @ t = 75.02 (199 (1.99%) infected)]
# 	13	tested due to symptoms  [+ 9 positive (69.23 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	13	tested TOTAL            [+ 9 positive (69.23 %) +]
# 	19 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	9 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	29 entered isolation
# [INTERVENTIONS @ t = 76.00 (210 (2.10%) infected)]
# 	16	tested due to symptoms  [+ 12 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	16	tested TOTAL            [+ 12 positive (75.00 %) +]
# 	24 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	28 entered isolation
# [INTERVENTIONS @ t = 77.01 (223 (2.23%) infected)]
# 	14	tested due to symptoms  [+ 11 positive (78.57 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	14	tested TOTAL            [+ 11 positive (78.57 %) +]
# 	24 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	11 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	33 entered isolation
# [INTERVENTIONS @ t = 78.01 (237 (2.37%) infected)]
# 	7	tested due to symptoms  [+ 3 positive (42.86 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	7	tested TOTAL            [+ 3 positive (42.86 %) +]
# 	16 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	3 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	36 entered isolation
# [INTERVENTIONS @ t = 79.02 (241 (2.41%) infected)]
# 	15	tested due to symptoms  [+ 13 positive (86.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 13 positive (86.67 %) +]
# 	18 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	27 entered isolation
# [INTERVENTIONS @ t = 80.00 (266 (2.66%) infected)]
# 	9	tested due to symptoms  [+ 5 positive (55.56 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	9	tested TOTAL            [+ 5 positive (55.56 %) +]
# 	21 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	21 entered isolation
# [INTERVENTIONS @ t = 81.00 (275 (2.75%) infected)]
# 	13	tested due to symptoms  [+ 12 positive (92.31 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	13	tested TOTAL            [+ 12 positive (92.31 %) +]
# 	19 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	12 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	34 entered isolation
# [INTERVENTIONS @ t = 82.01 (302 (3.02%) infected)]
# 	15	tested due to symptoms  [+ 13 positive (86.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	15	tested TOTAL            [+ 13 positive (86.67 %) +]
# 	23 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	13 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	24 entered isolation
# [INTERVENTIONS @ t = 83.02 (322 (3.22%) infected)]
# 	20	tested due to symptoms  [+ 15 positive (75.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	20	tested TOTAL            [+ 15 positive (75.00 %) +]
# 	23 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	35 entered isolation
# [INTERVENTIONS @ t = 84.00 (346 (3.46%) infected)]
# 	18	tested due to symptoms  [+ 14 positive (77.78 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	18	tested TOTAL            [+ 14 positive (77.78 %) +]
# 	29 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	14 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	36 entered isolation
# [INTERVENTIONS @ t = 85.01 (367 (3.67%) infected)]
# 	32	tested due to symptoms  [+ 27 positive (84.38 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	32	tested TOTAL            [+ 27 positive (84.38 %) +]
# 	34 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	27 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	44 entered isolation
# [INTERVENTIONS @ t = 86.00 (396 (3.96%) infected)]
# 	12	tested due to symptoms  [+ 10 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	12	tested TOTAL            [+ 10 positive (83.33 %) +]
# 	32 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	10 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	48 entered isolation
# [INTERVENTIONS @ t = 87.03 (415 (4.15%) infected)]
# 	22	tested due to symptoms  [+ 17 positive (77.27 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	22	tested TOTAL            [+ 17 positive (77.27 %) +]
# 	31 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	17 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	59 entered isolation
# [INTERVENTIONS @ t = 88.01 (434 (4.34%) infected)]
# 	18	tested due to symptoms  [+ 14 positive (77.78 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	18	tested TOTAL            [+ 14 positive (77.78 %) +]
# 	31 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	14 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	41 entered isolation
# [INTERVENTIONS @ t = 89.00 (455 (4.55%) infected)]
# 	14	tested due to symptoms  [+ 10 positive (71.43 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	14	tested TOTAL            [+ 10 positive (71.43 %) +]
# 	28 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	10 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	48 entered isolation
# [INTERVENTIONS @ t = 90.01 (485 (4.85%) infected)]
# 	18	tested due to symptoms  [+ 15 positive (83.33 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	18	tested TOTAL            [+ 15 positive (83.33 %) +]
# 	29 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	15 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	42 entered isolation
# [INTERVENTIONS @ t = 91.01 (505 (5.05%) infected)]
# 	30	tested due to symptoms  [+ 24 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	30	tested TOTAL            [+ 24 positive (80.00 %) +]
# 	40 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	24 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	39 entered isolation
# [INTERVENTIONS @ t = 92.00 (541 (5.41%) infected)]
# 	45	tested due to symptoms  [+ 32 positive (71.11 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	45	tested TOTAL            [+ 32 positive (71.11 %) +]
# 	64 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	32 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	55 entered isolation
# [INTERVENTIONS @ t = 93.01 (568 (5.68%) infected)]
# 	35	tested due to symptoms  [+ 28 positive (80.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# ...
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 128.15 (50 (0.50%) infected)]
# 	2	tested due to symptoms  [+ 2 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 2 positive (100.00 %) +]
# 	8 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 129.30 (50 (0.50%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	10 entered isolation
# [INTERVENTIONS @ t = 130.02 (50 (0.50%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 131.12 (47 (0.47%) infected)]
# 	5	tested due to symptoms  [+ 5 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	5	tested TOTAL            [+ 5 positive (100.00 %) +]
# 	6 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	5 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 132.16 (42 (0.42%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	7 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	7 entered isolation
# [INTERVENTIONS @ t = 133.27 (38 (0.38%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	5 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	12 entered isolation
# [NEW EXPOSURE @ t = 134.11 (2 exposed)]
# [INTERVENTIONS @ t = 134.11 (35 (0.35%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 135.47 (34 (0.34%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 136.39 (31 (0.31%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 137.19 (29 (0.29%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 138.10 (27 (0.27%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 140.13 (26 (0.26%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 141.13 (24 (0.24%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 142.42 (24 (0.24%) infected)]
# 	3	tested due to symptoms  [+ 2 positive (66.67 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	3	tested TOTAL            [+ 2 positive (66.67 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	2 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 143.37 (25 (0.25%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	4 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	5 entered isolation
# [INTERVENTIONS @ t = 145.02 (22 (0.22%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	6 entered isolation
# [INTERVENTIONS @ t = 146.31 (21 (0.21%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 147.09 (21 (0.21%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 148.73 (19 (0.19%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 149.11 (18 (0.18%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 150.34 (16 (0.16%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 151.33 (15 (0.15%) infected)]
# 	1	tested due to symptoms  [+ 1 positive (100.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 1 positive (100.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 152.26 (15 (0.15%) infected)]
# 	2	tested due to symptoms  [+ 1 positive (50.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	2	tested TOTAL            [+ 1 positive (50.00 %) +]
# 	3 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	1 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 153.52 (13 (0.13%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	4 entered isolation
# [INTERVENTIONS @ t = 154.36 (12 (0.12%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	3 entered isolation
# [INTERVENTIONS @ t = 155.07 (11 (0.11%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 156.53 (10 (0.10%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	0 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [NEW EXPOSURE @ t = 157.85 (1 exposed)]
# [INTERVENTIONS @ t = 157.85 (10 (0.10%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	0 entered isolation
# [INTERVENTIONS @ t = 158.17 (11 (0.11%) infected)]
# 	1	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	1	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	1 entered isolation
# [INTERVENTIONS @ t = 159.60 (10 (0.10%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	2 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# [INTERVENTIONS @ t = 160.00 (10 (0.10%) infected)]
# 	0	tested due to symptoms  [+ 0 positive (0.00 %) +]
# 	0	tested as traces        [+ 0 positive (0.00 %) +]
# 	0	tested randomly         [+ 0 positive (0.00 %) +]
# 	0	tested TOTAL            [+ 0 positive (0.00 %) +]
# 	1 will isolate due to symptoms         (0 as groupmates of symptomatic)
# 	0 will isolate due to positive test    (0 as groupmates of positive)
# 	0 will isolate due to positive contact (0 as groupmates of contact)
# 	2 entered isolation
# Trial(4) is done!

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(15,5))

plt.bar(avgPosCase_01.keys(),avgPosCase_01.values(),color = 'orange',label='No Circuit Breaker', alpha=0.5)
plt.bar(avgPosCase.keys(),avgPosCase.values(),label='Circuit Braker from Day 80',alpha=0.5)
plt.vlines([80],ymin=0,ymax=max(avgPosCase_01.values()),colors='black',linestyles='dashed',label='Day 80')

plt.xlabel("Days")
plt.ylabel("Number of Persons")
plt.legend()
plt.title("Number of Positive Cases with and without Circuit Breaker")
# Out:
# Text(0.5, 1.0, 'Number of Positive Cases with and without Circuit Breaker')
