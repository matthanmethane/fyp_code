# %%
import networkx as nx
from matplotlib.pyplot import figure
import matplotlib.patches as mpatches
from collections import Counter
import matplotlib.pyplot as plt
from SEIRNetwork import SEIRNetwork
import numpy as np
from statistics import mean
from math import log

# %%
SEIR_network = SEIRNetwork(generator_type='LFR')
G = SEIR_network.G_baseline

figure(figsize=(15,5))
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
degreeCount = Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

plt.bar(deg, cnt, width=0.80)

plt.title(f"Degree Distribution of LFR Contact Network")
plt.ylabel("Number of Nodes")
plt.xlabel("Degree")

mean_degree_patch = mpatches.Patch(label=f'Average Degree: {mean(degree_sequence)}')
plt.legend(handles=[mean_degree_patch])

# %%
min(degree_sequence),max(degree_sequence)
# Out:
# (3, 319)

# %%
SEIR_network = SEIRNetwork()
G = SEIR_network.G_baseline

from statistics import mean


figure(figsize=(15,5))
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
degreeCount = Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

plt.bar(deg, cnt, width=0.80)

plt.title(f"Degree Distribution of FARZ Contact Network")
plt.ylabel("Number of Nodes")
plt.xlabel("Degree")

mean_degree_patch = mpatches.Patch(label=f'Average Degree: {mean(degree_sequence)}')
plt.legend(handles=[mean_degree_patch])
# Out:
# Generated overall age distribution:
# 0-4: 0.0687	(0.0239 from target)
# 10-14: 0.0786	(0.0284 from target)
# 15-19: 0.0764	(0.0250 from target)
# 20-24: 0.0512	(-0.0084 from target)
# 25-29: 0.0585	(-0.0112 from target)
# 30-34: 0.0653	(-0.0102 from target)
# 35-39: 0.0607	(-0.0118 from target)
# 40-44: 0.0613	(-0.0121 from target)
# 45-49: 0.0617	(-0.0136 from target)
# 5-9: 0.0790	(0.0291 from target)
# 50-54: 0.0598	(-0.0119 from target)
# 55-59: 0.0639	(-0.0109 from target)
# 60-64: 0.0575	(-0.0134 from target)
# 65-69: 0.0572	(-0.0018 from target)
# 70-74: 0.0482	(0.0027 from target)
# 75-79: 0.0217	(-0.0011 from target)
# 80-84: 0.0169	(-0.0010 from target)
# 85-89: 0.0080	(-0.0014 from target)
# 90: 0.0054	(-0.0001 from target)
#
# Generated household size distribution:
# 1: 0.1472	(-0.0091 from target)
# 2: 0.2293	(-0.0089 from target)
# 3: 0.2252	(0.0113 from target)
# 4: 0.1985	(-0.0022 from target)
# 5: 0.1283	(0.0126 from target)
# 6: 0.0714	(-0.0037 from target)
# Num households: 3179
# mean household size: 3.1065084501977704
#
# Generating graph for 0-9...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 10-19...
# GENERATING WITH FARZ GENERATOR
# /Users/donghan37/Documents/Final Year Project/demo/.venv/lib/python3.8/site-packages/networkx/linalg/graphmatrix.py:187: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   return adjacency_matrix(G, nodelist, dtype, weight)
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 20-64...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# Generating graph for 65+...
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# GENERATING WITH FARZ GENERATOR
# /Users/donghan37/Documents/Final Year Project/demo/lib/models.py:673: RuntimeWarning: invalid value encountered in divide
#   self.delta_Q = numpy.log(self.degree_Q) / numpy.log(numpy.mean(self.degree_Q)) if self.parameters[

# %%
min(degree_sequence),max(degree_sequence)
# Out:
# (0, 137)

# %%
figure(figsize=(15,5))
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)  # degree sequence
degreeCount = Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

sum_cnt = sum(cnt)
cnt = [x/sum_cnt for x in cnt]

plt.scatter(deg, cnt)
plt.yscale('log')
plt.xscale('log')
plt.title(f"Log-Log Degree Distribution of LFR Contact Network")
plt.ylabel("Log of Number of Nodes")
plt.xlabel("Log of Degree")

mean_degree_patch = mpatches.Patch(label=f'Average Degree: {mean(degree_sequence)}')
plt.legend(handles=[mean_degree_patch])

# %%
nx.degree_pearson_correlation_coefficient(G)
# Out:
# -0.029630858232095686

# %%
nx.transitivity(G)
# Out:
# 0.046798053458962215
